# %%
import pandas as pd
import numpy as np
import csv
import nltk
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer 
# download the following packages if needed

#nltk.download('punkt')
#nltk.download('wordnet')
#nltk.download('stopwords')

from matplotlib import pyplot as plt
from sklearn.metrics import roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import precision_recall_curve, average_precision_score


from sklearn.model_selection import cross_val_predict

import os

import re



from tqdm import tqdm
tqdm.pandas()


#getting a library of stopwords and defining a lemmatizer
porter=SnowballStemmer("english")
lmtzr = WordNetLemmatizer()

stop_words = set(stopwords.words('english'))

#set paths for input and output
path='C:\\Dropbox\\Lucy and Diveena\\Data coding project'

spitout='C:\\Dropbox\\Violence and Tourism\\Replication\\03 Paper\\figures\\'
dataspitout='C:\\Dropbox\\Violence and Tourism\\Replication\\02 Code\\00_ML\\'


#spitout='C:\\Dropbox\\Violence and Tourism\\Replication\\03 Paper\\figures\\'


#additional functions

#the following leaves in place two or more capital letters in a row
#will be ignored when using standard stemming
def abbr_or_lower(word):
    if re.match('([A-Z]+[a-z]*){2,}', word):
        return word
    else:
        return word.lower()

#modular pipeline for stemming, lemmatizing and lowercasing
def tokenize(text, modulation):
    tokens = re.split(r'\W+', text)
    stems = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        lowers=abbr_or_lower(token)
        if lowers not in stop_words:
            if re.search('[a-zA-Z]', lowers):
                if modulation==1:
                    stems.append(porter.stem(lowers))
                if modulation==2:
                    stems.append(lmtzr.lemmatize(lowers))
                if modulation==0:
                    stems.append(lowers)
                stems.append(" ")
    return "".join(stems)

#Functions to make figures and save them
def draw_precision_curve(y,x,name):
    precision, recall, thresholds = precision_recall_curve(y, x)
    avprec=average_precision_score(y, x)

    plt.plot(recall, precision, lw=5, label='Av.Precision = %0.2f)' % (avprec))

    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision/Recall Curve')
    plt.legend(loc="lower left")
    plt.savefig(spitout+name+'.pdf')
    plt.show()

def draw_roc_curve(y,x,name):
    fpr, tpr, thresholds = roc_curve(y,x)
    roc_auc = auc(fpr, tpr)


    plt.plot(fpr,tpr, lw=5, label='AUC = %0.2f)' % (roc_auc))

    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower left")
    plt.savefig(spitout+name+'.pdf')
    plt.show()
    
    
def separation_plot(pdata, fname, alpha=1):
    '''
    Display observed events against predicted probabilities for binary classification problems
    Arguments
    ---------
        y_true : vector of observed class labels
        y_pred : vector of predicted probabilities
        fname: file path to directory to save plot 
        alpha: float from 0 to 1, transparency of indicators of observed events
    '''
    #normalization
    pdata=(pdata-pdata.min())/(pdata.max()-pdata.min())
    
    #wrangling
    pdata.columns = ['y', 'yhat']
    pdata = pdata.sort_values('yhat')
    pdata = pdata.reset_index(drop=True)

    events = pdata[pdata['y'] == 1]

    evals = events.index.values


    plt.figure(figsize=(20, 5))
    plt.ylabel('Predicted Score')
    ax = plt.gca()
    ax.set_xlim([1, (evals[-1] + 1)])
    ax.set_ylim([0, 1])
    

    rr = 0
    for i in evals:
        if rr == 0:
            ax.axvline(x=i, linewidth=0.2, linestyle='-', color='k', alpha=alpha, label = 'True Positives', zorder=2)
            rr = 1
        else:
            ax.axvline(x=i, linewidth=0.2, linestyle='-', color='k', alpha=alpha, zorder=1)
    
    ax.plot(pdata['yhat'], linestyle='--', color='red', lw = 4, label = 'Predicted Score', zorder=3)
    ax.set_xlabel('Rank of prediction')
    ax.legend(loc="upper left")
    plt.savefig(fname)
    plt.show()
    plt.close()

# %%
#loading the data

filename ="extended_data_train.csv"
corpus_data = pd.read_csv(os.path.join(path, filename), sep=',', encoding='utf-8')
corpus_data.info()


mod=2 #=1 means stemming, =2 means lemmatizing, =0 just lowercase
#pre-process title
tit_preproc = (
    corpus_data.TITLE_EN
    .astype(str)
    .progress_apply(lambda row: tokenize(row, mod))
)

corpus_data["titles_lemm"]=tit_preproc

#pre-process text
text_preproc = (
    corpus_data.TXT_EN
    .astype(str)
    .progress_apply(lambda row: tokenize(row, mod))
)

corpus_data["text_with_head_lemm"]=text_preproc

print("done with text plus titles")

corpus_data = corpus_data.dropna(subset=['titles_lemm']).reset_index(drop=True)

corpus_data  = corpus_data[['ARTICLENUMID','issuing_iso3c','dest_iso3c', 'year','monthnum','day', 'TITLE_EN','text_with_head_lemm'
                            , 'titles_lemm', 'label_0','label_1','label_2','label_3', 'LENGTH']]


        
#second dataset
path_test='C:\\Dropbox\\Lucy and Diveena\\Google Translate'
filename_test ="FACTIVA.TRANS.v2.csv"

test_data = pd.read_csv(os.path.join(path_test, filename_test), sep=',', encoding='utf-8')

test_data.rename(columns = {'ID':'ARTICLENUMID'}, inplace = True)
test_data.rename(columns = {'TRANSLATED_SD':'TXT_EN'}, inplace = True)
test_data.rename(columns = {'HEADLINE_TRANSLATED':'TITLE_EN'}, inplace = True)
test_data['label_0'] = np.nan
test_data['label_1'] = np.nan
test_data['label_2'] = np.nan
test_data['label_3'] = np.nan

test_data=test_data.dropna(subset=['TITLE_EN'])

test_data=test_data.reset_index()

test_data['day']=test_data.date.str[-2:]

test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249905 entries, 0 to 249904
# Data columns (total 19 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     249905 non-null  int64
#  1   ARTICLENUMID   249905 non-null  object
#  2   LOADDATE       249905 non-null  object
#  3   LENGTH         249905 non-null  object
#  4   year           249900 non-null  float64
#  5   day            216617 non-null  float64
#  6   monthnum       249900 non-null  float64
#  7   issuing_iso3c  249905 non-null  object
#  8   dest_iso3c     249905 non-null  object
#  9   LANGUAGE_SD    249905 non-null  object
#  10  TXT_EN         249905 non-null  object
#  11  GTD_EVETDATE   47781 non-null   object
#  12  GTD_NKILL      47781 non-null   float64
#  13  GTD_EVENTID    47781 non-null   float64
#  14  label_0        35346 non-null   float64
#  15  label_1        24412 non-null   float64
#  16  label_2        24412 non-null   float64
#  17  label_3        24412 non-null   float64
#  18  TITLE_EN       249905 non-null  object
# dtypes: float64(9), int64(1), object(9)
# memory usage: 36.2+ MB
# 100%|███████████████████████████████████████████████████████████████████████| 249905/249905 [00:17<00:00, 14481.45it/s]
# 100%|█████████████████████████████████████████████████████████████████████████| 249905/249905 [04:48<00:00, 864.77it/s]
# done with text plus titles
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262854 entries, 0 to 262853
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   index          262854 non-null  int64
#  1   ARTICLENUMID   262854 non-null  object
#  2   DATE           262854 non-null  object
#  3   LENGTH         262854 non-null  object
#  4   LANG           262854 non-null  object
#  5   HEADLINE       262432 non-null  object
#  6   CONTENT        262853 non-null  object
#  7   ff             262854 non-null  object
#  8   CONTENT_CLEAN  262853 non-null  object
#  9   DYAD           262397 non-null  object
#  10  issuing_iso3c  262397 non-null  object
#  11  dest_iso3c     262397 non-null  object
#  12  TXT_EN         262835 non-null  object
#  13  TITLE_EN       262854 non-null  object
#  14  date           262854 non-null  object
#  15  year           262854 non-null  int64
#  16  monthnum       262854 non-null  int64
#  17  label_0        0 non-null       float64
#  18  label_1        0 non-null       float64
#  19  label_2        0 non-null       float64
#  20  label_3        0 non-null       float64
#  21  day            262854 non-null  object
# dtypes: float64(4), int64(3), object(15)
# memory usage: 44.1+ MB

# %%
lmtzr = WordNetLemmatizer()
new_stopwords = set(stopwords.words('english'))

mod=0 #=1 means stemming, =2 means lemmatizing, =0 just lowercase

#pre-process title
tit_preproc = (
    test_data.TITLE_EN
    .astype(str)
    .progress_apply(lambda row: tokenize(row, mod))
)

test_data["titles_lemm"]=tit_preproc

#pre-process text
text_preproc = (
    test_data.TXT_EN
    .astype(str)
    .progress_apply(lambda row: tokenize(row, mod))
)

test_data["text_with_head_lemm"]=text_preproc

print("done with text plus titles")

test_data = test_data.dropna(subset=['titles_lemm']).reset_index(drop=True)

test_data  = test_data[['ARTICLENUMID','issuing_iso3c','dest_iso3c', 'year','monthnum','day', 'TITLE_EN','text_with_head_lemm'
                        , 'titles_lemm','label_0','label_1','label_2','label_3', 'LENGTH']]

test_data.to_csv('test_beforemerge_test.csv',sep=',',encoding='utf-8')

full_data = pd.concat([corpus_data,test_data], join = "inner")
full_data.reset_index()
full_data.info()
full_data.to_csv('test_lemmatized_test.csv',sep=',',encoding='utf-8')
del test_data
del corpus_data
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 262854/262854 [00:08<00:00, 29765.06it/s]
# 100%|████████████████████████████████████████████████████████████████████████| 262854/262854 [03:51<00:00, 1133.02it/s]
# done with text plus titles
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 512759 entries, 0 to 262853
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ARTICLENUMID         512759 non-null  object
#  1   issuing_iso3c        512302 non-null  object
#  2   dest_iso3c           512302 non-null  object
#  3   year                 512754 non-null  float64
#  4   monthnum             512754 non-null  float64
#  5   day                  479471 non-null  object
#  6   TITLE_EN             512759 non-null  object
#  7   text_with_head_lemm  512759 non-null  object
#  8   titles_lemm          512759 non-null  object
#  9   label_0              35346 non-null   float64
#  10  label_1              24412 non-null   float64
#  11  label_2              24412 non-null   float64
#  12  label_3              24412 non-null   float64
#  13  LENGTH               512759 non-null  object
# dtypes: float64(6), object(8)
# memory usage: 58.7+ MB

# %%
full_data.label_1.value_counts()
# Out:
# 0.0    19589
# 1.0     4823
# Name: label_1, dtype: int64

# %%
import pandas as pd
import numpy as np
import csv
import re

import xgboost as xgb

from pprint import pprint
from time import time
import logging

import nltk                                                             # Natural language Toolkit
from nltk.stem import SnowballStemmer                                   # Porter's II Stemmer
from nltk import word_tokenize                                          # Document tokenizer
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer

from matplotlib import pyplot as plt

from sklearn.metrics import roc_curve, auc, confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve, average_precision_score

from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer, TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

from sklearn import tree

import os

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz

from tqdm import tqdm
tqdm.pandas()

from collections import Counter



# uploading the data
filename ="test_lemmatized_test.csv"

# uploading the data
full_data = pd.read_csv(os.path.join(dataspitout, filename), sep=',', encoding='utf-8')
full_data.info()

full_data['titles_lemm'] = full_data['titles_lemm'].astype(str)
full_data['text_with_head_lemm'] = full_data['text_with_head_lemm'].astype(str)
#four times title following Cage
full_data['title_text']=full_data['text_with_head_lemm']+full_data['titles_lemm']+full_data['titles_lemm']+full_data['titles_lemm']+full_data['titles_lemm']
# Out:
# C:\Users\HMueller\anaconda3\lib\site-packages\xgboost\compat.py:31: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512759 entries, 0 to 512758
# Data columns (total 15 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           512759 non-null  int64
#  1   ARTICLENUMID         512759 non-null  object
#  2   issuing_iso3c        512302 non-null  object
#  3   dest_iso3c           512302 non-null  object
#  4   year                 512754 non-null  float64
#  5   monthnum             512754 non-null  float64
#  6   day                  479471 non-null  float64
#  7   TITLE_EN             512759 non-null  object
#  8   text_with_head_lemm  512747 non-null  object
#  9   titles_lemm          511619 non-null  object
#  10  label_0              35346 non-null   float64
#  11  label_1              24412 non-null   float64
#  12  label_2              24412 non-null   float64
#  13  label_3              24412 non-null   float64
#  14  LENGTH               512759 non-null  object
# dtypes: float64(7), int64(1), object(7)
# memory usage: 58.7+ MB

# %%
#countries condemning violence elsewhere
searchstrings=['turkey condemns', 'egypt condemns', 'tunisia condemns', 'israel condemns', 'morocco condemns']
Tlist=[]
for s in full_data.titles_lemm:
    r = re.compile("|".join(r"\b%s\b" % w for w in searchstrings))
    wordcount = Counter(re.findall(r, s))
    #if sum(wordcount.values())>0:
    #    print(s)
    Tlist.append(sum(wordcount.values()))
full_data['condemns']=Tlist
full_data['condemns'].value_counts()
# Out:
# 0    511725
# 1      1034
# Name: condemns, dtype: int64

# %%
#use dictionary to filter destinations

searchstrings=["tunisia", "tunisian","tunisians", "tunis","sousse", "Tunisia", "Tunisian","TUNISIA"]
Tlist=[]
Length=[]
for s in full_data.title_text:
    r = re.compile("|".join(r"\b%s\b" % w for w in searchstrings))
    wordcount = Counter(re.findall(r, s))
    Tlist.append(sum(wordcount.values()))
    Length.append(len(s))
full_data['tunisia_count']=Tlist

searchstrings=["egypt", "egyptian","egyptians", "cairo", "sinai", "Egypt", "Egyptian","EGYPT","CAIRO", "hurghada","mubarak"]
Tlist=[]
Length=[]
for s in full_data.title_text:
    r = re.compile("|".join(r"\b%s\b" % w for w in searchstrings))
    wordcount = Counter(re.findall(r, s))
    Tlist.append(sum(wordcount.values()))
    Length.append(len(s))
full_data['egypt_count']=Tlist

searchstrings=["gaza","palestinian","palestine", "israel", "israelian","israelis","jerusalem","israeli", "netanyahu", "tel aviv", "sinai","bethlehem", "Israel", "Israelian","ISRAEL"]
Tlist=[]
Length=[]
for s in full_data.title_text:
    r = re.compile("|".join(r"\b%s\b" % w for w in searchstrings))
    wordcount = Counter(re.findall(r, s))
    Tlist.append(sum(wordcount.values()))
    Length.append(len(s))
full_data['israel_count']=Tlist

searchstrings=["turkey", "turkish","turks","istanbul","ankara","erdogan" "Turkey", "Turkish","TURKEY"]
Tlist=[]
Length=[]
for s in full_data.title_text:
    r = re.compile("|".join(r"\b%s\b" % w for w in searchstrings))
    wordcount = Counter(re.findall(r, s))
    Tlist.append(sum(wordcount.values()))
    Length.append(len(s))
full_data['turkey_count']=Tlist

searchstrings=["morocco", "moroccan", "moroccans","rabat","Morocco", "Moroccan", "marrakesh", "MOROCCO"]
Tlist=[]
Length=[]
for s in full_data.title_text:
    r = re.compile("|".join(r"\b%s\b" % w for w in searchstrings))
    wordcount = Counter(re.findall(r, s))
    Tlist.append(sum(wordcount.values()))
    Length.append(len(s))
full_data['morocco_count']=Tlist

full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512759 entries, 0 to 512758
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           512759 non-null  int64
#  1   ARTICLENUMID         512759 non-null  object
#  2   issuing_iso3c        512302 non-null  object
#  3   dest_iso3c           512302 non-null  object
#  4   year                 512754 non-null  float64
#  5   monthnum             512754 non-null  float64
#  6   day                  479471 non-null  float64
#  7   TITLE_EN             512759 non-null  object
#  8   text_with_head_lemm  512759 non-null  object
#  9   titles_lemm          512759 non-null  object
#  10  label_0              35346 non-null   float64
#  11  label_1              24412 non-null   float64
#  12  label_2              24412 non-null   float64
#  13  label_3              24412 non-null   float64
#  14  LENGTH               512759 non-null  object
#  15  title_text           512759 non-null  object
#  16  condemns             512759 non-null  int64
#  17  tunisia_count        512759 non-null  int64
#  18  egypt_count          512759 non-null  int64
#  19  israel_count         512759 non-null  int64
#  20  turkey_count         512759 non-null  int64
#  21  morocco_count        512759 non-null  int64
# dtypes: float64(7), int64(7), object(8)
# memory usage: 86.1+ MB

# %% [markdown]
# for text in full_data[(full_data["morocco_count"]==0)&(full_data["dest_iso3c"]=="MAR")].title_text:
#     print(text)
#     print("   ")

# %% [markdown]
# for text in full_data[(full_data["turkey_count"]==0)&(full_data["dest_iso3c"]=="TUR")].title_text:
#     print(text)
#     print("   ")

# %% [markdown]
# for text in full_data[(full_data["israel_count"]==0)&(full_data["dest_iso3c"]=="ISR")].title_text:
#     print(text)
#     print("   ")

# %% [markdown]
# for text in full_data[(full_data["egypt_count"]==0)&(full_data["dest_iso3c"]=="EGY")].title_text:
#     print(text)
#     print("   ")

# %% [markdown]
# for text in full_data[(full_data["tunisia_count"]==0)&(full_data["dest_iso3c"]=="TUN")].title_text:
#     print(text)
#     print("   ")

# %%
full_data=full_data[((full_data["israel_count"]>0)&(full_data["dest_iso3c"]=="ISR")) |
          ((full_data["morocco_count"]>0)&(full_data["dest_iso3c"]=="MAR")) |
          ((full_data["turkey_count"]>0)&(full_data["dest_iso3c"]=="TUR")) |
          ((full_data["tunisia_count"]>0)&(full_data["dest_iso3c"]=="TUN")) |
          ((full_data["egypt_count"]>0)&(full_data["dest_iso3c"]=="EGY"))]

# %% [markdown]
# # Start the Training Data

# %%
data_train = full_data[pd.notna(full_data.label_0)].reset_index()
data_train  = data_train[['issuing_iso3c','dest_iso3c', 'year','monthnum','day', 'title_text', 'text_with_head_lemm', 'titles_lemm','label_0','label_1','label_2','label_3']]

#if label 0 is 0 the likelihood that the other two are 0 is overwhelming. Therefore carry over 0 coding.
data_train["label_1"][(data_train.label_1.isna())&(data_train.label_0==0)]=0
data_train["label_2"][(data_train.label_2.isna())&(data_train.label_0==0)]=0
data_train["label_3"][(data_train.label_3.isna())&(data_train.label_0==0)]=0

data_train.info()

#start training
#label_0 and label_3 are not used. One is too general (all violence) and the other too specific (fata violence of tourists).
#this do file will therefore only use label_1 and label_2


labels_0 = data_train.label_0.tolist()
labels_1 = data_train.label_1.tolist()
labels_2 = data_train.label_2.tolist()
labels_3 = data_train.label_3.tolist()
Titles = data_train.titles_lemm.tolist()
Texts = data_train.text_with_head_lemm.tolist()
Fourtit_text=data_train.title_text.tolist()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35233 entries, 0 to 35232
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   issuing_iso3c        35233 non-null  object
#  1   dest_iso3c           35233 non-null  object
#  2   year                 35233 non-null  float64
#  3   monthnum             35233 non-null  float64
#  4   day                  35233 non-null  float64
#  5   title_text           35233 non-null  object
#  6   text_with_head_lemm  35233 non-null  object
#  7   titles_lemm          35233 non-null  object
#  8   label_0              35233 non-null  float64
#  9   label_1              35233 non-null  float64
#  10  label_2              35233 non-null  float64
#  11  label_3              35233 non-null  float64
# dtypes: float64(7), object(5)
# memory usage: 3.2+ MB

# %% [markdown]
# # Dictionary Method
#
# We implemented a simple dictionary method for spotting fatal violence and harm to tourist in news articles. This serves more to illustrate the advantages and limits of the method than a serious attempt to develop the perfect dictionary.
#
# But our dictionary method also not a straw man - we spent considerable time trying different features and combining them in additive and multiplicative ways. More specifically, we followed the intuition that a tourist harm index should follow a multiplicative logic of tourist*harm and tried to implement this logic in two different ways: 1) we used lists of bigrams that contain both the word tourist and some word indicating harm 2) we made counts of both and multiplied them.
#
# At the end we realized that an additive index performs better and therefore simply added monograms and bigrams across lists up to generate the index shown in the paper.

# %%
#Tourist harm method one: bigrams
searchstrings=["attack tourist", "attacked tourist","kill tourist","killed tourist","killing tourist","massacre tourist",
               "massacred tourist","tourist attack","tourist killed","tourist kidnapped","tourist wounded",
               "attack tourists", "attacked tourists","kill tourists","killed tourists","killing tourists","massacre tourists",
               "massacred tourists","tourists attack","tourists killed","tourists kidnapped","tourists wounded"]
Tlist=[]
Length=[]
for s in data_train.title_text:
    r = re.compile("|".join(r"\b%s\b" % w for w in searchstrings))
    wordcount = Counter(re.findall(r, s))
    Tlist.append(sum(wordcount.values()))
    Length.append(len(s))
data_train['T_H_count']=Tlist
data_train['alength']=Length

data_train['T_H_count'].value_counts() 

#Tourist harm method one: two lists of monograms
searchstrings=["attack", "attacked", "kill", "killed", "murder", "murdered", "massacre","massacred", "kidnap",
               "kidnapped", "injur", "injured", "wound", "wounded", "terror"]
Hlist=[]
Length=[]
for s in data_train.title_text:
    r = re.compile("|".join(r"\b%s\b" % w for w in searchstrings))
    wordcount = Counter(re.findall(r, s))
    Hlist.append(sum(wordcount.values()))
data_train['H_count']=Hlist

searchstrings=["tourist", "tourists"]
Tlist=[]
Length=[]
for s in data_train.title_text:
    r = re.compile("|".join(r"\b%s\b" % w for w in searchstrings))
    wordcount = Counter(re.findall(r, s))
    Tlist.append(sum(wordcount.values()))
data_train['T_count']=Tlist

#violence list
searchstrings=["fatality", "kill", "killed", "massacred", "murdered", "violence", "violent","attack",
               "attacked","injur", "injured", "hit","death","dead"]
Klist=[]
Length=[]
for s in data_train.title_text:
    r = re.compile("|".join(r"\b%s\b" % w for w in searchstrings))
    wordcount = Counter(re.findall(r, s))
    Klist.append(sum(wordcount.values()))
data_train['K_count']=Klist

#We tried relative counts as well but this always makes things worse
data_train['tourist_harm_1']=data_train['T_H_count']
data_train['tourist_harm_2']=(data_train['T_count']+data_train['H_count']+data_train['T_H_count'])
data_train['fatal_harm']=data_train['K_count']

# %%
#AUC performance
print("Score reached with dictionary method on fatalities:", roc_auc_score(labels_1, data_train['fatal_harm']))
print("Score reached with dictionary method 1 on tourist violence:", roc_auc_score(labels_2, data_train['tourist_harm_1']))
print("Score reached with dictionary method 2 on tourist violence:", roc_auc_score(labels_2, data_train['tourist_harm_2']))
# Out:
# Score reached with dictionary method on fatalities: 0.890786563860838
# Score reached with dictionary method 1 on tourist violence: 0.6309132737668383
# Score reached with dictionary method 2 on tourist violence: 0.9014261947048524

# %%
draw_roc_curve(labels_1, data_train['fatal_harm'],"dictionary_fatal_viol_roc_curve")

draw_precision_curve(labels_1, data_train['fatal_harm'],"dictionary_fatal_viol_precision_curve")

draw_roc_curve(labels_2, data_train['tourist_harm_2'],"dictionary_tourist_harm_precision_curve")

draw_precision_curve(labels_2, data_train['tourist_harm_2'],"dictionary_tourist_harm_precision_curve")

#Model critique



sep_data=data_train[["label_2",'tourist_harm_2']]
name=spitout + "separation_plot_dictionary_tourism.pdf"
separation_plot(sep_data, name)

# %% [markdown]
# # Supervised
# ## Label 0

# %%
import random
random.seed(42)

# %%
#RF
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", MultinomialNB()),
    ]
)


parameters = {
    "vect__max_df": ([0.4]),
    "vect__min_df": ([0.007]),
    "vect__ngram_range": ([(1,3)]),  # unigrams or bigrams
    "tfidf__use_idf": ([False]),
    'tfidf__norm': (['l2']),
}

# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=3)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_0)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 0:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'tfidf__norm': ['l2'],
#  'tfidf__use_idf': [False],
#  'vect__max_df': [0.4],
#  'vect__min_df': [0.007],
#  'vect__ngram_range': [(1, 3)]}
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# done in 59.598s
#
# Best score: 0.899
# Best parameters set for label 0:
# 	tfidf__norm: 'l2'
# 	tfidf__use_idf: False
# 	vect__max_df: 0.4
# 	vect__min_df: 0.007
# 	vect__ngram_range: (1, 3)

# %%
clf_nb0 = grid_search.best_estimator_
y_pred_nb0 = cross_val_predict(clf_nb0, Fourtit_text, labels_0, n_jobs=4, verbose=2, cv=3, method= 'predict_proba')[:,1]
draw_roc_curve(labels_0, y_pred_nb0 ,"ml_nb_any_harm_roc_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   29.3s finished

# %%
data_train.label_0.value_counts()
# Out:
# 0.0    27988
# 1.0     7245
# Name: label_0, dtype: int64

# %% [markdown]
# ### XGB boost label 0

# %%
#xgb
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", xgb.XGBClassifier()),
    ]
)


parameters = {
    "vect__max_df": ([0.4]),
    "vect__min_df": (0.008,0.009),
    "vect__ngram_range": ([(1,3)]),  # unigrams or bigrams
    "tfidf__use_idf": ([True]),
    'tfidf__norm': (['l1']),
    "clf__gamma": ([1]),
    "clf__reg_alpha": ([20]),
    "clf__reg_lambda": ([0.1]),
    "clf__max_depth": ([20]),
    "clf__n_estimators": ([300]),
    "clf__min_child_weight": ([10]),
    "clf__scale_pos_weight": ([28090/7256]),
    "clf__colsample_bytree":([0.7]),
}


# Find the best parameters for both the feature extraction and the
# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=3)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_0)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 0:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'clf__colsample_bytree': [0.7],
#  'clf__gamma': [1],
#  'clf__max_depth': [20],
#  'clf__min_child_weight': [10],
#  'clf__n_estimators': [300],
#  'clf__reg_alpha': [20],
#  'clf__reg_lambda': [0.1],
#  'clf__scale_pos_weight': [3.871278941565601],
#  'tfidf__norm': ['l1'],
#  'tfidf__use_idf': [True],
#  'vect__max_df': [0.4],
#  'vect__min_df': (0.008, 0.009),
#  'vect__ngram_range': [(1, 3)]}
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# C:\Users\HMueller\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:04:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# done in 687.629s
#
# Best score: 0.901
# Best parameters set for label 0:
# 	clf__colsample_bytree: 0.7
# 	clf__gamma: 1
# 	clf__max_depth: 20
# 	clf__min_child_weight: 10
# 	clf__n_estimators: 300
# 	clf__reg_alpha: 20
# 	clf__reg_lambda: 0.1
# 	clf__scale_pos_weight: 3.871278941565601
# 	tfidf__norm: 'l1'
# 	tfidf__use_idf: True
# 	vect__max_df: 0.4
# 	vect__min_df: 0.009
# 	vect__ngram_range: (1, 3)

# %%
clf_xgb0 = grid_search.best_estimator_
y_pred_xgb0 = cross_val_predict(clf_xgb0, Fourtit_text, labels_0, n_jobs=4, verbose=2, cv=3, method= 'predict_proba')[:,1]
draw_roc_curve(labels_0, y_pred_xgb0 ,"ml_xgb_any_harm_roc_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:  4.9min finished

# %%
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", RandomForestClassifier()),
    ]
)

parameters = {
    "vect__max_df": (0.4,0.5),
    "vect__min_df": (0.005,0.006),
    "vect__ngram_range": ([(1,1)]),  # unigrams or bigrams
    "tfidf__use_idf": ([True]),
    'tfidf__norm': (['l1']),
    "clf__max_depth": ([20]),
    "clf__n_estimators": ([300]),
    "clf__min_samples_leaf": ([10]),
    "clf__class_weight": (["balanced"]),
}

# Find the best parameters for both the feature extraction and the
# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=3)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_0)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 0:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'clf__class_weight': ['balanced'],
#  'clf__max_depth': [20],
#  'clf__min_samples_leaf': [10],
#  'clf__n_estimators': [300],
#  'tfidf__norm': ['l1'],
#  'tfidf__use_idf': [True],
#  'vect__max_df': (0.4, 0.5),
#  'vect__min_df': (0.005, 0.006),
#  'vect__ngram_range': [(1, 1)]}
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# done in 347.494s
#
# Best score: 0.900
# Best parameters set for label 0:
# 	clf__class_weight: 'balanced'
# 	clf__max_depth: 20
# 	clf__min_samples_leaf: 10
# 	clf__n_estimators: 300
# 	tfidf__norm: 'l1'
# 	tfidf__use_idf: True
# 	vect__max_df: 0.5
# 	vect__min_df: 0.005
# 	vect__ngram_range: (1, 1)

# %%
clf_rf0 = grid_search.best_estimator_
y_pred_rf0 = cross_val_predict(clf_rf0, Fourtit_text, labels_0, n_jobs=4, verbose=2, cv=3, method= 'predict_proba')[:,1]
draw_roc_curve(labels_0, y_pred_rf0 ,"ml_rf_any_harm_roc_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:  1.3min finished

# %% [markdown]
# ### Putting everything together for label 0

# %%
y_pred_ens0=(y_pred_nb0 + y_pred_xgb0 + y_pred_rf0 )/3

draw_roc_curve(labels_0, y_pred_ens0 ,"ml_ens_any_harm_roc_curve")

draw_precision_curve(labels_0, y_pred_ens0 ,"ml_ens_any_harm_precision_curve")

# %%
#dummyfy
y_ens_dum0=(y_pred_ens0>0.5)*1

cm = confusion_matrix(labels_0, y_ens_dum0, labels=clf_rf0.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf_rf0.classes_)
disp.plot()
plt.show()

# %% [markdown]
# # Label 1

# %%
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", MultinomialNB()),
    ]
)


parameters = {
    "vect__max_df": ([0.4]),
    "vect__min_df": ([0.007]),
    "vect__ngram_range": ([(1,3)]),  # unigrams or bigrams
    "tfidf__use_idf": ([False]),
    'tfidf__norm': (['l2']),
}

# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=3)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_1)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 1:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'tfidf__norm': ['l2'],
#  'tfidf__use_idf': [False],
#  'vect__max_df': [0.4],
#  'vect__min_df': [0.007],
#  'vect__ngram_range': [(1, 3)]}
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# done in 74.242s
#
# Best score: 0.929
# Best parameters set for label 1:
# 	tfidf__norm: 'l2'
# 	tfidf__use_idf: False
# 	vect__max_df: 0.4
# 	vect__min_df: 0.007
# 	vect__ngram_range: (1, 3)

# %%
clf_nb1 = grid_search.best_estimator_
y_pred_nb1 = cross_val_predict(clf_nb1, Fourtit_text, labels_1, n_jobs=4, verbose=2, cv=3, method= 'predict_proba')[:,1]
draw_roc_curve(labels_1, y_pred_nb1 ,"ml_nb_fatal_harm_roc_curve")
draw_precision_curve(labels_1, y_pred_nb1,"ml_nb_fatal_harm_precision_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:   48.4s finished

# %%
#xgb
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", xgb.XGBClassifier()),
    ]
)


parameters = {
    "vect__max_df": (0.3, 0.4),
    "vect__min_df": ([0.007]),
    "vect__ngram_range": ([(1,3)]),  # unigrams or bigrams
    "tfidf__use_idf": ([True]),
    'tfidf__norm': (['l1']),
    "clf__gamma": ([1]),
    "clf__reg_alpha": ([20]),
    "clf__reg_lambda": ([0.1]),
    "clf__max_depth": ([20]),
    "clf__n_estimators": ([300]),
    "clf__min_child_weight": ([10]),
    "clf__scale_pos_weight": ([30523/4823]),
    "clf__colsample_bytree":([0.5]),
}


# Find the best parameters for both the feature extraction and the
# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=3)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_1)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 1:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'clf__colsample_bytree': [0.5],
#  'clf__gamma': [1],
#  'clf__max_depth': [20],
#  'clf__min_child_weight': [10],
#  'clf__n_estimators': [300],
#  'clf__reg_alpha': [20],
#  'clf__reg_lambda': [0.1],
#  'clf__scale_pos_weight': [6.328633630520423],
#  'tfidf__norm': ['l1'],
#  'tfidf__use_idf': [True],
#  'vect__max_df': (0.3, 0.4),
#  'vect__min_df': [0.007],
#  'vect__ngram_range': [(1, 3)]}
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# C:\Users\HMueller\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:31:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# done in 792.681s
#
# Best score: 0.939
# Best parameters set for label 1:
# 	clf__colsample_bytree: 0.5
# 	clf__gamma: 1
# 	clf__max_depth: 20
# 	clf__min_child_weight: 10
# 	clf__n_estimators: 300
# 	clf__reg_alpha: 20
# 	clf__reg_lambda: 0.1
# 	clf__scale_pos_weight: 6.328633630520423
# 	tfidf__norm: 'l1'
# 	tfidf__use_idf: True
# 	vect__max_df: 0.3
# 	vect__min_df: 0.007
# 	vect__ngram_range: (1, 3)

# %%
clf_xgb1 = grid_search.best_estimator_
y_pred_xgb1 = cross_val_predict(clf_xgb1, Fourtit_text, labels_1, n_jobs=4, verbose=2, cv=3, method= 'predict_proba')[:,1]
draw_roc_curve(labels_1, y_pred_xgb1 ,"ml_xgb_fatal_harm_roc_curve")
draw_precision_curve(labels_1, y_pred_xgb1,"ml_xgb_fatal_harm_precision_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:  5.1min finished

# %%
# Parameters to use for grid search. Uncommenting more parameters will give
# better exploring power but will increase processing time in a combinatorial
# way
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", RandomForestClassifier()),
    ]
)

parameters = {
    "vect__max_df": (0.3,0.4),
    "vect__min_df": ([0.008]),
    "vect__ngram_range": ([(1,1)]),  # unigrams or bigrams
    "tfidf__use_idf": ([True]),
    'tfidf__norm': (['l1']),
    "clf__max_depth": ([20]),
    "clf__n_estimators": ([300]),
    "clf__min_samples_leaf": ([10]),
    "clf__class_weight": (["balanced"]),
}

# Find the best parameters for both the feature extraction and the
# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=3)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_1)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 1:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'clf__class_weight': ['balanced'],
#  'clf__max_depth': [20],
#  'clf__min_samples_leaf': [10],
#  'clf__n_estimators': [300],
#  'tfidf__norm': ['l1'],
#  'tfidf__use_idf': [True],
#  'vect__max_df': (0.3, 0.4),
#  'vect__min_df': [0.008],
#  'vect__ngram_range': [(1, 1)]}
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# done in 287.420s
#
# Best score: 0.938
# Best parameters set for label 1:
# 	clf__class_weight: 'balanced'
# 	clf__max_depth: 20
# 	clf__min_samples_leaf: 10
# 	clf__n_estimators: 300
# 	tfidf__norm: 'l1'
# 	tfidf__use_idf: True
# 	vect__max_df: 0.3
# 	vect__min_df: 0.008
# 	vect__ngram_range: (1, 1)

# %%
clf_rf1 = grid_search.best_estimator_
y_pred_rf1 = cross_val_predict(clf_rf1, Fourtit_text, labels_1, n_jobs=4, verbose=2, cv=3, method= 'predict_proba')[:,1]
draw_roc_curve(labels_1, y_pred_rf1 ,"ml_rf_fatal_harm_roc_curve")
draw_precision_curve(labels_1, y_pred_rf1,"ml_rf_fatal_harm_precision_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:  1.6min finished

# %% [markdown]
# ### Putting everything together for label 1

# %%
y_pred_ens1=(y_pred_nb1 + y_pred_xgb1 + y_pred_rf1 )/3

draw_roc_curve(labels_1, y_pred_ens1 ,"ml_ens_fatal_harm_roc_curve")

draw_precision_curve(labels_1, y_pred_ens1 ,"ml_ens_fatal_harm_precision_curve")

# %%
#dummyfy
y_ens_dum1=(y_pred_ens1>0.5)*1

cm = confusion_matrix(labels_1, y_ens_dum1, labels=clf_rf1.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf_rf1.classes_)
disp.plot()
plt.show()

# %% [markdown]
# ## Label 2

# %%
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", MultinomialNB()),
    ]
)


parameters = {
    "vect__max_df": ([0.3]),
    "vect__min_df": ([0.01]),
    "vect__ngram_range": ([(1,3)]),  # unigrams or bigrams
    "tfidf__use_idf": ([True]),
    'tfidf__norm': (['l2']),
}

# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=3)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_2)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 2:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'tfidf__norm': ['l2'],
#  'tfidf__use_idf': [True],
#  'vect__max_df': [0.3],
#  'vect__min_df': [0.01],
#  'vect__ngram_range': [(1, 3)]}
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# done in 94.163s
#
# Best score: 0.943
# Best parameters set for label 2:
# 	tfidf__norm: 'l2'
# 	tfidf__use_idf: True
# 	vect__max_df: 0.3
# 	vect__min_df: 0.01
# 	vect__ngram_range: (1, 3)

# %%
clf_nb2 = grid_search.best_estimator_
y_pred_nb2 = cross_val_predict(clf_nb2, Fourtit_text, labels_2, n_jobs=4, verbose=2, cv=3, method= 'predict_proba')[:,1]
draw_roc_curve(labels_2, y_pred_nb2 ,"ml_nb_tourist_harm_roc_curve")
draw_precision_curve(labels_2, y_pred_nb2,"ml_nb_tourist_harm_precision_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:  1.0min finished

# %%
#xgb
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", xgb.XGBClassifier()),
    ]
)


parameters = {
    "vect__max_df": ([0.25]),
    "vect__min_df": (0.004, 0.005),
    "vect__ngram_range": ([(1,3)]),  # unigrams or bigrams
    "tfidf__use_idf": ([True]),
    'tfidf__norm': (['l1']),
    "clf__gamma": ([1]),
    "clf__reg_alpha": ([15]),
    "clf__reg_lambda": ([0.1]),
    "clf__max_depth": ([25]),
    "clf__n_estimators": ([300]),
    "clf__min_child_weight": ([5]),
    "clf__scale_pos_weight": ([10]),
    "clf__colsample_bytree":([0.2]),
}

# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=3)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_2)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 2:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'clf__colsample_bytree': [0.2],
#  'clf__gamma': [1],
#  'clf__max_depth': [25],
#  'clf__min_child_weight': [5],
#  'clf__n_estimators': [300],
#  'clf__reg_alpha': [15],
#  'clf__reg_lambda': [0.1],
#  'clf__scale_pos_weight': [10],
#  'tfidf__norm': ['l1'],
#  'tfidf__use_idf': [True],
#  'vect__max_df': [0.25],
#  'vect__min_df': (0.004, 0.005),
#  'vect__ngram_range': [(1, 3)]}
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# C:\Users\HMueller\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [16:53:31] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# done in 346.227s
#
# Best score: 0.968
# Best parameters set for label 2:
# 	clf__colsample_bytree: 0.2
# 	clf__gamma: 1
# 	clf__max_depth: 25
# 	clf__min_child_weight: 5
# 	clf__n_estimators: 300
# 	clf__reg_alpha: 15
# 	clf__reg_lambda: 0.1
# 	clf__scale_pos_weight: 10
# 	tfidf__norm: 'l1'
# 	tfidf__use_idf: True
# 	vect__max_df: 0.25
# 	vect__min_df: 0.004
# 	vect__ngram_range: (1, 3)

# %%
clf_xgb2 = grid_search.best_estimator_
y_pred_xgb2 = cross_val_predict(clf_xgb2, Fourtit_text, labels_2, n_jobs=4, verbose=2, cv=3, method= 'predict_proba')[:,1]
draw_roc_curve(labels_2, y_pred_xgb2 ,"ml_nb_tourist_harm_roc_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:  2.1min finished

# %%
# Parameters to use for grid search. Uncommenting more parameters will give
# better exploring power but will increase processing time in a combinatorial
# way
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", RandomForestClassifier()),
    ]
)

parameters = {
    "vect__max_df": ([0.4]),
    "vect__min_df": ([0.004]),
    "vect__ngram_range": ([(1,1)]),  # unigrams or bigrams
    "tfidf__use_idf": ([True]),
    'tfidf__norm': (['l1']),
    "clf__max_depth": ([20]),
    "clf__n_estimators": ([300]),
    "clf__min_samples_leaf": ([10]),
    "clf__class_weight": (["balanced"]),
}

# Find the best parameters for both the feature extraction and the
# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=3)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_2)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 2:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'clf__class_weight': ['balanced'],
#  'clf__max_depth': [20],
#  'clf__min_samples_leaf': [10],
#  'clf__n_estimators': [300],
#  'tfidf__norm': ['l1'],
#  'tfidf__use_idf': [True],
#  'vect__max_df': [0.4],
#  'vect__min_df': [0.004],
#  'vect__ngram_range': [(1, 1)]}
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# done in 118.340s
#
# Best score: 0.967
# Best parameters set for label 2:
# 	clf__class_weight: 'balanced'
# 	clf__max_depth: 20
# 	clf__min_samples_leaf: 10
# 	clf__n_estimators: 300
# 	tfidf__norm: 'l1'
# 	tfidf__use_idf: True
# 	vect__max_df: 0.4
# 	vect__min_df: 0.004
# 	vect__ngram_range: (1, 1)

# %%
clf_rf2 = grid_search.best_estimator_
y_pred_rf2 = cross_val_predict(clf_rf2, Fourtit_text, labels_2, n_jobs=4, verbose=2, cv=3, method= 'predict_proba')[:,1]
draw_roc_curve(labels_2, y_pred_rf2 ,"ml_rf_tourist_harm_roc_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   3 out of   3 | elapsed:  1.2min finished

# %% [markdown]
# ### Putting everything together for label 2

# %%
y_pred_ens2=(y_pred_nb2 + y_pred_xgb2 + y_pred_rf2 )/3

draw_roc_curve(labels_2, y_pred_ens2 ,"ml_ens_tourist_harm_roc_curve")

draw_precision_curve(labels_2, y_pred_ens2 ,"ml_ens_tourist_harm_precision_curve")

# %%
data_train['y_pred_ens2']=y_pred_ens2
sep_data=data_train[["label_2",'y_pred_ens2']]
name=spitout + "separation_plot_ml_tourism.pdf"
separation_plot(sep_data, name)

# %%
#dummyfy
y_ens_dum2=(y_pred_ens2>0.5)*1

cm = confusion_matrix(labels_2, y_ens_dum2, labels=clf_rf2.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf_rf2.classes_)
disp.plot()
plt.show()

# %%
i=0
for text in data_train.title_text[(data_train["label_2"]==0)&(data_train['y_pred_ens2']>0.5)]:
    print("Full text for article:",i)
    print(text)
    print("  ")
    i+=1
# Out:
# Full text for article: 0
# turkey france hit attack recent month istanbul turkey tourism industry also taken hit following bomb attack capital ankara october suicide bomber tuesday killed people left wounded istanbul tourist district sultanahmet near major tourist attraction including blue mosque hagia sophia killed german tourist make largest share holidaymaker turkey threatening industry car bomb attack thursday kurdish militant police station housing officer killed wounded score people southeastern turkey turkey already lost russian tourist due weakening rouble spat russia another big supplier visitor chebib said estimated loss turkey tourism income reach billion john podaras partner consultancy hotel development resource said attack bound longer term implication turkish tourism industry turkey tourism profit fell per cent billion third quarter chebib said turkey attracted million visitor generated billion tourism revenue anand said cox king take precaution guide tourist alternate destination following attack turkey france etihad airway early ass impact etihad airway flight booking following recent attack paris istanbul spokesperson abu dhabi airline told gulf news email outside europe egypt tourism industry suffering egypt tourism minister hisham zaazou said last month direct revenue loss tourism since plane crash range million million attack dent tourism popular holiday destination attack dent tourism popular holiday destination attack dent tourism popular holiday destination attack dent tourism popular holiday destination
#
# Full text for article: 1
# tunisia plan arm tourism police deploy hundred reinforcement boost security jihadist gunned people seaside resort police sunday patrolled beach port el kantaoui north sousse worst jihadist attack tunisia history took place friday monday interior minister britain france germany visit seaside riu imperial marhaba hotel south tunis killing took place tunisia interior ministry spokesman mohamed ali aroui refused comment allegation police slow react extra police armed guard protect tourist extra police armed guard protect tourist extra police armed guard protect tourist extra police armed guard protect tourist
#
# Full text for article: 2
# BYLINE ruth pollard middle east correspondent tunis tunisia neighbourhood north west tunisia capital tunis one clutch poor town extremist mosque allowed flourish since overthrow president zine el abidine ben ali one unlicensed mosque city kairouan islamic state inspired gunman seifeddine rezgui believed exposed radical teaching fuelled friday devastating attack one tunisia best known beach resort operating outside state control estimated mosque slated closure tunisian government struggle respond worst ever terror attack soil least people mostly tourist britain ireland germany belgium well several tunisian killed june lone gunman armed kalashnikov grenade attacked sunbather beach resort town sousse kilometre south capital many tunisian despairing government ongoing failure stop extremist gaining foothold say could forced better balance country newly evolving democracy emboldened islamist movement emerging decade harsh repression former president point assassination two left wing politician attack national bardo museum march people killed mostly foreign tourist clear indication extremism growing threat tunisia monday mark one year since self declared leader abu bakr al baghdadi declared caliphate across territory stretch iraq syria libya north sinai region egypt terrorism expert estimate least tunisian gone fight libya iraq syria leaving tunisia unenviable distinction providing foreign fighter islamic state country world rafaa tebib tunis based security expert researcher universite francois rabelais france say government political fight terrorism lay blame foot tunisia moderate islamist party ennada say provided cover renegade mosque gain foothold community say even though islamic state indicated desire take territory tunisia yet managed turned jihad driven solely economic factor say tunisian political analyst youssef cherif economy part ideology tunisia something well entrenched population generation know belongs tunisia muslim world arab world GRAPHIC PHOTO tourist bear flower tunisian flag site deadly attack marhaba beach photo getty image extremism thrives fertile soil poverty revolt beach bloodbath radical mosque slated closure extremism thrives fertile soil poverty revolt beach bloodbath radical mosque slated closure extremism thrives fertile soil poverty revolt beach bloodbath radical mosque slated closure extremism thrives fertile soil poverty revolt beach bloodbath radical mosque slated closure
#
# Full text for article: 3
# slaughter tunisia claim life gentle sydney man terror attack family tragedy tuesday ship docked tunisia mr camelo parent among group tourist decided visit national bardo museum country capital tunis GRAPHIC THREE PHOTOS clockwise top javier camelo selfie father jose mother miriam italian city palermo javier parent graduation last week tunisian force secure museum following attack photo facebook AFP slaughter tunisia claim life gentle sydney man terror attack family tragedy slaughter tunisia claim life gentle sydney man terror attack family tragedy slaughter tunisia claim life gentle sydney man terror attack family tragedy slaughter tunisia claim life gentle sydney man terror attack family tragedy
#
# Full text for article: 4
# tunisian security force wednesday killed dangerous terrorist arrested others confiscated weapon ammunition anti terrorism operation near tunisian capital according interior ministry said planned carry simultaneous terrorist operation police came around GMT two hour exchange fire woman preferred named said gunman neighborhood recently rented house solidarity solidarity stronghold salafist jihadist movement tunisia november suicide bomber hossam al abdali year old resident district manihila blew bus presidential security personnel near headquarters ministry interior heart tunisian capital killed security personnel process adopted islamic state dictator zine el abidine ben ali violence jihadi group escalated tunisia one linked al qaeda islamic maghreb planned turn tunisia first islamic emirate north africa foreign tourist security personnel killed three deadly attack adopted islamic extremist state organization tunisian age killed tunisia since according official statistic military security personnel foreign tourist tunisian national especially syria iraq libya according report released last july UN working group use mercenary tunisian police kill two terrorist stop planned simultaneous attack tunisian police kill two terrorist stop planned simultaneous attack tunisian police kill two terrorist stop planned simultaneous attack tunisian police kill two terrorist stop planned simultaneous attack
#
# Full text for article: 5
# jeddah mar19 BNA OIC secretary general mr iyad ameen madani strongly condemned terrorist attack took place wednesday morning march bardo national museum tunis capital republic tunisia resulted several casualty injury among foreign tourist tunisian citizen secretary general voiced view terrorist attack run counter every human principle antithesis every religious tenet undermine social fabric obstruct building political institution deny right people secure stable life madani expressed OIC full solidarity people government tunisia combating terrorism confronting seek disrupt country security stability derail economy development tarnish history stand model coexistence tolerance enlightenment also secretary general stressed need combat phenomenon terrorism understand context dismantle environment nurture delegitimize slogan track party feed use achieve political agenda ensure proponent supporter tracked security force brought justice context secretary general reiterated OIC principled unwavering position condemns terrorism form manifestation also extended sincere condolence family victim best wish prompt recovery injured h NBNA GMT publishing right reserved bahrain news agency OIC condemns bardo museum terror attack OIC condemns bardo museum terror attack OIC condemns bardo museum terror attack OIC condemns bardo museum terror attack
#
# Full text for article: 6
# bahrain condemns terrorist attack tunisia manama mar BNA ministry foreign affair kingdom bahrain today strongly condemns terrorist attack targeted headquarters parliament republic tunisia bardo museum claiming life number tourist innocent tunisian citizen ministry warns cowardly terrorist attack target accelerated tangible effort exerted brotherly republic tunisia underpin stability security also affirms kingdom bahrain support necessary crucial measure republic tunisia take secure citizen resident safety confront extremism terrorism land ministry foreign affair express sincere condolence kingdom bahrain relative family innocent casualty wish speedy recovery injured terrorist act reiterates rejection form violence terrorism regardless motif justification also affirms solidarity international community effort aiming root terrorism eliminate manifestation risk maintain international security stability MJBNA GMT 18publishing right reserved bahrain news agency bahrain condemns terrorist attack tunisia bahrain condemns terrorist attack tunisia bahrain condemns terrorist attack tunisia bahrain condemns terrorist attack tunisia
#
# Full text for article: 7
# egypt archaeological complex luxor bank nile river already targeted tourist two occasion six member al gama al islamiyya terrorist organization killed tourist four egyptian citizen hatshepsut temple june year man bomber left four wounded temple karnak morocco may explosion killed people casablanca april bomb exploded cafe city marrakesh leaving people dead tunisia march year three gunman stormed bardo museum tunisian capital killing people including tourist end june year old seifeddine rezgui opened fire guest imperial marhaba hotel sousse killing tourist british sightseeing sightseeing sightseeing sightseeing
#
# Full text for article: 8
# NEW YORK family canadian volunteer dedicated alleviating poverty africa group fearless german traveling turkey middle east iraqi went baghdad take refuge jihadist violence hometown speech therapist fell love indonesia among victim terrorist attack last week four country bloodshed left friend relative stunned randomness killing site attack targeted conventional mall iraq hotel ouagadougou capital burkina faso shopping mall jakarta traditional sultanahmet square historical cultural heart istanbul attack also highlight growing rivalry islamic state al qaeda organization determined prove jihadist faith barbarism istanbul suicide bomber crowd near blue mosque hagia sophia apparently chose group german tourist arrived day dead retired including butcher teacher construction manager father son gã¼nther steffen hã ppner also died blast karin franke dã¼tz year old daughter retired teacher recalled anxiety felt learned mother going turkey common destiny tragedy common destiny tragedy common destiny tragedy common destiny tragedy
#
# Full text for article: 9
# president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus explosion struck bus carrying member tunisia presidential guard capital tuesday killing least people wounding dozen others government described terrorist attack blast tree lined avenue heart tunis new blow country seen model region struggled islamic extremist violence radical gunman staged two attack earlier year killed people devastated tourism industry rattled young democracy president beji caid essebsi bus time declared state emergency curfew tunis region convened emergency meeting security council wednesday morning speaking national television said tunisia war terrorism urged international co operation extremist killed hundred around europe mideast recent week paris beirut russian plane shot egypt police fanned throughout central tunis tuesday explosion ambulance rushed scene evacuating wounded dead top government minister visited scene attack cordoned police earlier month tunisian authority announced dismantling cell said planned attack police station hotel seaside city sousse kilometre southeast tunis sousse one target attack earlier year u secretary state john kerry visiting tunis earlier month pledged expanded economic security support tunisia whose popular uprising unleashed democracy movement across region known arab spring tunisia arab spring country solidified new democracy facing serious economic security challenge tourism industry hit especially hard year shooting luxury beach hotel sousse last june killed people mostly tourist march attack islamist extremist tunisia famed bardo museum near capital killed people president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus
#
# Full text for article: 10
# ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism one guy tunisia one guy france one guy kuwait three loose cannon wreaking havoc deadly disparate decentralized havoc three different way single day friday strike indeed leaderless hardest blow came fragile tunisia lone gunman posing tourist cut least people mediterranean beach resort sousse hardest simply blow landed overwhelmingly vacationer future traveller dare set foot country another devastating day tunisia coming le six month attack tourist bardo museum tunis several year attack timed holy month tunisian blogger activist lina ben mhenni told star mhenni faced repeated threat speaking extremism travel bodyguard assigned tunisian interior ministry even though object heavy handed nature reconstituted police state revolution intended overthrow mhenni ended conversation abruptly single security escort arrived join hour long drive sousse rally beginning take shape stand solidarity everyone civilian tourist worker foreigner tunisian alike suffered today ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism
#
# Full text for article: 11
# dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france attack friday tunisia kuwait france raised fear adherent islamic state following order tunisia soon gunman reportedly disguised tourist opened umbrella pulled kalashnikov shooting least people death beach resort security force killed tunisia high alert since march gunman attacked bardo museum tunis killing undoubtedly hurt country vital tourism industry islamic state claim responsibility SITE intelligence group report could indication group increasing interest tunisia hailed sole remaining success story arab spring could also part battle al qaeda insurgent country gained strength among unemployed disenfranchised tunisian youth newer generation loyal islamic state dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france
#
# Full text for article: 12
# dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france muslim embark hasten toward jihad abu mohammed al adnani said message circulated social medium attack friday tunisia kuwait france raised fear adherent islamic state following order tunisia soon gunman reportedly disguised tourist opened umbrella pulled kalashnikov shooting least people death beach resort security force killed tunisia high alert since march gunman attacked bardo museum tunis killing undoubtedly hurt country vital tourism industry islamic state claim responsibility SITE intelligence group report could indication group increasing interest tunisia hailed sole remaining success story arab spring could also part battle al qaeda insurgent country gained strength among unemployed disenfranchised tunisian youth newer generation loyal islamic state dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france
#
# Full text for article: 13
# third suspect tunisia identified yet caught tunisian security force looking third man suspected wednesday attack national bardo museum foreign tourist tunisian police officer two gunman killed tunisian shaken attack massacre heart capital right next parliament islamic state group smaller extremist movement okba ibn nafaa claimed responsibility interior ministry released footage two gunman walking museum lobby along corridor attack one point encounter man descending flight stair appear exchange brief greeting hurriedly departs man among people arrested suspected accomplice ministry also released photograph gunman killed security force identified yassine abidi hatem khachnaoui kasserine western tunisia official said police still searching maher ben moudli kaidi believe co ordinated attack resident working class area northern tunis abidi lived said kaidi also lived nearby yet abidi action divided neighbourhood attending funeral neighbour relative muslim society like tunisia obligation yet said would revolted done third suspect tunisia identified yet caught third suspect tunisia identified yet caught third suspect tunisia identified yet caught third suspect tunisia identified yet caught
#
# Full text for article: 14
# warning tip iceberg group calling yemeni branch islamic state claimed responsibility friday pair suicide bombing sanaa killed people injured hundred others true attack yemen war torn capital would mark deadliest islamic state assault outside stronghold iraq syria bloodshed came heel siege wednesday bardo museum tunisia people died michelle shephard report escalating violence yemen mitch potter examines aftermath tunis taking measure badly wednesday attack rocked cradle arab spring full story a14 deadly expansion islamic state deadly expansion islamic state deadly expansion islamic state deadly expansion islamic state
#
# Full text for article: 15
# islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist tunisian authority said two slain gunman clear link extremist analyst said existing militant cell merely inspired group rather deliberately establishing presence across north africa four others said supporter cell also arrested central tunisia far group claiming allegiance al qaeda north african branch active health ministry said death toll rose thursday foreign tourist nearly people wounded three tunisian killed including two attacker tunisian stepped around trail blood broken glass outside museum rally solidarity victim foreign tourist cruise ship country fledgling democracy marcher carried sign saying terrorism tunisia bloodied still standing claiming responsibility attack islamic state group issued statement audio jihadi website applauding dead gunman knight blessed invasion one den infidel vice muslim tunisia several well armed group neighbouring chaotic libya already pledged allegiance islamic state based iraq syria attack magnitude tunisia country emerge arab spring uprising functioning democracy raised concern spread extremism rest north africa confronted poor economy young tunisian disproportionately gone abroad fight extremist group libya syria iraq including affiliated islamic state upon return home may decided carry attack tunisian authority estimated young people left country fight radical group returned tunisia deadly group oqba ibn nafaa brigade allied al qaeda based mountain near algerian border previously confined attack political figure security service tunisia particularly vulnerable attack economy struggled since country became birthplace arab spring overthrowing dictator death many foreigner damage tunisia tourism industry draw thousand foreigner beach oasis ancient roman ruin industry started recover year decline two cruise ship passenger among dead quickly left tunis early thursday islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist
#
# Full text for article: 16
# gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year foreign tourist scrambled panic wednesday militant stormed museum tunisia capital killed least people shooting anything moved witness said authority launched manhunt two three accomplice attack official said killed people nearly tourist poland italy spain germany colombia least two people killed gunman tunisian people several country injured attack authority said poland reported wounded italy said least six hospital tunis doctor said also french japanese belgian patient want people tunisia understand firstly lastly war terror savage minority group frighten u said newly elected president beji caid essebsi evening address nation fight continue exterminated tunisian overthrew dictator kicked arab spring spread across region uprising built new democracy country also struggled economic problem attack extremist prime minister habib essid identified slain gunman yassine laabidi hatem khachnaoui tunisian twitter account associated extremist islamic state group based syria iraq described overjoyed attack urging tunisian follow brother according rita katz SITE u based organization monitor militant group assault bardo tunisia largest museum housed 15th century palace began sometime noon local time score european tourist visiting dozen tourist scrambled museum linking arm clutching child tunisian police security force pointed weapon building museum fourkilometres city centre located near national parliament building evacuated hour police ended siege thousand tunisian flocked downtown landmark bourguiba avenue revolution took place nighttime rally chanted free tunisia defiance terrorism tunisia stable country region struggled violence islamic extremist sworn allegiance al qaeda islamic state group disproportionately large number tunisian recruit according government estimate joined islamic state fighter syria iraq many received training neighbouring libya gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year
#
# Full text for article: 17
# backgrounder deadly attack egypt since least one french tourist killed people wounded blast cairo populous al hussein district sunday evening following major deadly attack hit egypt recent year april suicide bomber wounded seven including two israeli italian swede near egyptian museum downtown cairo april explosion near open market downtown cairo killed least four people including french woman two french suspected suicide bomber wounded others oct series bombing taba hilton hotel egypt sinai peninsula killed including israeli injured sept egyptian security force attacked islamic militant searching hideout suburb cairo killed four militant nov gunman killed foreign tourist four egyptian ancient temple near southern city luxor attack dealt heavy blow country tourist sector sept two gunman killed nine german tourist egyptian driver outside museum downtown cairo april four islamic militant shot dead greek tourist wounded others outside hotel cairo oct militant attacked bus southern egypt killing british tourist injuring three british tourist egyptian driver sept gunman killed two german tourist two egyptian red sea resort hurghada aug gunman killed year old spanish boy injured three others firing tourist bus southern egypt march islamic militant fired nile cruiser southern egypt killing german woman tourist nov motorcade egyptian prime minister muhammad naquib sedki attacked passing school sedki escaped attack unscathed school girl killed least injured feb bomb blew coffee shop downtown cairo killing one swede turk egyptian wounding others british woman tourist killed southern egypt egyptian writer criticized religious extremist shot dead gunman riding motorcycle backgrounder deadly attack egypt since backgrounder deadly attack egypt since backgrounder deadly attack egypt since backgrounder deadly attack egypt since
#
# Full text for article: 18
# backgrounder deadly attack egypt since least one french tourist killed people wounded blast cairo populous al hussein district sunday evening following major deadly attack hit egypt recent year april suicide bomber wounded seven including two israeli italian swede near egyptian museum downtown cairo april explosion near open market downtown cairo killed least four people including french woman two french suspected suicide bomber wounded others oct series bombing taba hilton hotel egypt sinai peninsula killed including israeli injured sept egyptian security force attacked islamic militant searching hideout suburb cairo killed four militant nov gunman killed foreign tourist four egyptian ancient temple near southern city luxor attack dealt heavy blow country tourist sector sept two gunman killed nine german tourist egyptian driver outside museum downtown cairo april four islamic militant shot dead greek tourist wounded others outside hotel cairo oct militant attacked bus southern egypt killing british tourist injuring three british tourist egyptian driver sept gunman killed two german tourist two egyptian red sea resort hurghada aug gunman killed year old spanish boy injured three others firing tourist bus southern egypt march islamic militant fired nile cruiser southern egypt killing german woman tourist nov motorcade egyptian prime minister muhammad naquib sedki attacked passing school sedki escaped attack unscathed school girl killed least injured feb bomb blew coffee shop downtown cairo killing one swede turk egyptian wounding others british woman tourist killed southern egypt egyptian writer criticized religious extremist shot dead gunman riding motorcycle backgrounder deadly attack egypt since backgrounder deadly attack egypt since backgrounder deadly attack egypt since backgrounder deadly attack egypt since
#
# Full text for article: 19
# belarus strongly condemns terrorist attack turkey belarusian foreign ministry wednesday strongly categorically condemned terrorist attack airport istanbul terrorist attack turkey attack taken place europe demonstrated strong threat posed terrorism recognizes border norm civilization ministry said statement belarusian president alexander lukashenko behalf people belarus personally extended sincere condolence turkish president recep tayyip erdogan relative loved one people killed terrorist attack three suicide bomber opened fire blew international terminal istanbul ataturk airport tuesday killing least people injuring others belarusian consulate istanbul wednesday morning reported according preliminary data belarusian among victim incident belarusian foreign ministry recommended belarusian tourist refrain visiting crowded place turkey turkey declared day national mourning wednesday deadly istanbul airport attack belarus strongly condemns terrorist attack turkey belarus strongly condemns terrorist attack turkey belarus strongly condemns terrorist attack turkey belarus strongly condemns terrorist attack turkey
#
# Full text for article: 20
# backgrounder recent terror attack turkey glance terrorist attack istanbul ataturk airport tuesday killed people injured many others latest spate terror attack country station town midyat southeastern turkey killed three shuttle bus central istanbul main tourist district central istanbul shopping tourism district wounding least people bomber later identified turkish capital city ankara killing least people istanbul historic sultanahmet square islamic state istanbul sabiha gokcen airport located asian side others wounded two blast hit ankara central railway deadly attack kind turkish soil backgrounder recent terror attack turkey glance backgrounder recent terror attack turkey glance backgrounder recent terror attack turkey glance backgrounder recent terror attack turkey glance
#
# Full text for article: 21
# denmark expanding travel order egypt GYPT danish tourist advised go part egypt sharm el sheikh efter bomb attack bus sunday killed four people danish ministry foreign affair changing travel guide egypt popular holiday destination sharm el sheikh last place sinai peninsula tourist still travel safely according travel guide denmark extends travel order egypt denmark extends travel order egypt denmark extends travel order egypt denmark extends travel order egypt
#
# Full text for article: 22
# tunisia corner SalafismoDATELINE TunisiaApproaching al fatah mosque long street liberty see several row men sidewalk praying orderly manner pin inside friday prayer muezzin sung call prayer minute one afternoon temple center tunis meter great synagogue fatah one tunisian mosque symbol rise salafism stream strict islam many target violence shake wednesday brutality terrorist attack bardo museum people tourist murdered tunisia corner salafism tunisia corner salafism tunisia corner salafism tunisia corner salafism
#
# Full text for article: 23
# tunisia corner SalafismoDATELINE TunisiaApproaching al fatah mosque long street liberty see several row men sidewalk praying orderly manner pin inside friday prayer muezzin sung call prayer minute one afternoon temple center tunis meter great synagogue fatah one tunisian mosque symbol rise salafism stream strict islam many target violence shake wednesday brutality terrorist attack bardo museum people tourist murdered tunisia corner salafism tunisia corner salafism tunisia corner salafism tunisia corner salafism
#
# Full text for article: 24
# tunisia advanced process democratic transition unique arab world time country seriously affected terrorist violence high level jihadist mobilization death wednesday least foreign tourist including two spaniard three tunisian assault carried several armed men together parliament tunisia subsequent entrenchment hostage taking nearby bardo museum constitute expression violence mobilization number attack tunisia multiplied extraordinarily since half perpetrated military although police religious figure institution well citizen whose conduct conform rigorism demanded islamic extremist also target usual violence perpetrated mainly ansar al sharia tunisia AST also al qaeda islamic maghreb AQIM maintains link AST al morabitãºn okba bin nafa aligned state islamic EI salafists jihadist developed easily tunisia general amnesty overthrow president ben ali allowed many latter leave prison mid following assassination two important opposition leader islamist ennahda distance AST designate terrorist organization meanwhile tunisia became country jihadist mobilization related syria iraq reached greater height tunisian joined ISI al nusra front hundred returned others relocated IS libya implies serious potential political destabilization social bankruptcy tunisia even though citizen accept secularized exercise politics favor democracy tourism great importance economic development country therefore consolidation new regime since one attack tourist interest october sousse precisely first suicide country since april also tourist target yerba attempting parliament killing tourist tunisia unity government nida tune secular party parliamentary election october presidential election december ennahda jihadist present clear immediate strategy tunisian authority adequately respond terrorist challenge european one offer unequivocal support complicated lasting task PG fernando reinares principal investigator global terrorism program elcano royal institute terrorism democracy terrorism democracy terrorism democracy terrorism democracy
#
# Full text for article: 25
# four people including three believed south korean christian pilgrim killed yesterday bomb tore bus near egypt border israel sinai peninsula bus heading taba border crossing taking pilgrim visit st catherine monastery foot mount sinai front half engulfed explosion bombing said authority likely work terrorist insurgent based sinai marked dramatic shift current campaign egyptian regime date targeted military police tour company including take thousand british visitor egypt red sea beach every year fear herald return previous bombing campaign targeting people killed bomb one three planted time peninsula exploded taba hilton hotel le mile point yesterday attack pilgrim killed bomb attack sinai bus pilgrim killed bomb attack sinai bus pilgrim killed bomb attack sinai bus pilgrim killed bomb attack sinai bus
#
# Full text for article: 26
# AT LEAST people killed morocco yesterday suspected suicide bomber detonated device busy square tourist marrakesh khalid naciri communication minister compared attack one casablanca may left people dead including suicide bomber terrorist act said deliberate criminal act morocco facing threat may deal determinedly although one yet claimed responsibility attack men claiming moroccan member al qaida north african wing appeared video last week threatening attack moroccan interest foreign office estimate british tourist visit morocco year many head straight marrakesh developed chic reputation bountiful market architecture steeped history killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh
#
# Full text for article: 27
# AT LEAST people killed morocco yesterday one briton injured suspected suicide bomber detonated device busy square tourist marrakesh terrorist act said deliberate criminal act morocco facing threat may deal determinedly although one yet claimed responsibility attack men claiming moroccan member al qaeda north african wing appeared video last week threatening attack moroccan interest foreign office estimate british tourist visit morocco year killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh
#
# Full text for article: 28
# BRITAIN placed heightened alert police announced extra security public event weekend following terror attack france tunisia kuwait last night foreign office urged tourist imperial marhaba hotel hotel club riu bellevue tunisia stay indoors advertise location attacker might still large shooting beach left least dead including number briton travel company airline said holidaymaker fly tunisia could change plan free charge tunisia become key target jihadist attack one country undergone relatively successful transition democracy following arab spring remained open western value time contributed foreign jihadist war syria anywhere else march people killed attack bardo museum tunis tourist apart security officer cleaning lady BRITAIN placed britain alert copycat attack major event BRITAIN placed britain alert copycat attack major event BRITAIN placed britain alert copycat attack major event BRITAIN placed britain alert copycat attack major event
#
# Full text for article: 29
# tunisian police sacked museum attack world bulletin five leading tunisian security official sacked yesterday last week terrorist attack tourist tunis museum people killed ousted official include director tunisia tourist police police chief neighbourhood around national bardo museum tunisian police sacked museum attack world bulletin tunisian police sacked museum attack world bulletin tunisian police sacked museum attack world bulletin tunisian police sacked museum attack world bulletin
#
# Full text for article: 30
# third gunman run tunis museum massacre twenty foreign tourist policeman killed wednesday attack tunis first assault claimed islamic state iraq levant isil north african country birthplace arab spring interior ministry said saturday issued arrest warrant maher ben moudli kaidi tunisian suspect described dangerous terrorist element people believed linked atrocity also arrested tunisia newspaper yesterday demanded authority combat extremism essential really take action le quotidien wrote including control mosque influence uncontrollable religious fanatic le temp called urgent draconian measure withdrawing citizenship terrorist pledge allegiance enemy authority say many tunisian gone iraq syria libya join isil jihadist group tunisian soldier killed two others injured yesterday vehicle hit landmine planted terrorist mountainous region near algerian border third gunman run tunis museum massacre third gunman run tunis museum massacre third gunman run tunis museum massacre third gunman run tunis museum massacre
#
# Full text for article: 31
# tunis massacre gunman trained militant libya terror camp two gunman massacred people attack museum tunis week trained militant libya isil establishing presence terrorist slipped across border december received weapon training neighbouring country said rafik chelli secretary state security added tunisian authority detail exactly trained group name location several suspected training camp libya including benghazi derna city isil foothold isil claimed responsibility attack lauding gunman knight caliphate praising blessed invasion one den infidel vice muslim tunisia clear whether isil organised assault national bardo museum directly gave blessing operation executed militant speculation gunman link oqba ibn nafaa brigade allied al qaeda based mountain near algerian border gunman yassine laabidi hatem khachnaoui killed people tunisian policeman tourist including sally adey retired solicitor shropshire tunis massacre gunman trained militant libya terror camp tunis massacre gunman trained militant libya terror camp tunis massacre gunman trained militant libya terror camp tunis massacre gunman trained militant libya terror camp
#
# Full text for article: 32
# tunisia stunned home grown terror POLICE tunisia arrested nine people connection terrorist attack bardo museum yesterday british woman named among tourist killed islamic state iraq levant isil claimed responsibility wednesday attack two gunman armed kalashnikov assault rifle fired indiscriminately inside museum tunis british woman died identified sally adey retired solicitor shropshire whose husband robert survived shooting raid shocked tunisia regarded bastion moderate islam success story emerge arab spring fear attack could cripple country vital tourism sector isil praised two gunman shot dead police audio recording arabic calling knight islamic state dead terrorist dressed sweatshirt trainer identi fied hatem al khashnawi yassin al abidi reportedly tunisian abidi spent time iraq libya according tunisian medium report known authority anything special said habib essid tunisian prime minister affiliation clear moment added tourist killed wednesday attack nearly dozen country including france belgium italy spain poland australia colombia tunisia nine travelled MSC splendida cruise ship docked port tunis hour shooting simply police searching people thought terrorist venture despite moderate view tunisian country harbour hard core islamist extremist emerged since democratic revolution four year ago tunisian believed make largest foreign contingent fighting isil around volunteer flocking syria iraq recently libya two large cruise ship company costa cruise MSC cruise said cancelled stop tunis time two german tour company said halting trip tunis nearby beach resort former head britain counter terrorism service warned yesterday vast number holidaymaker travelling turkey summer would make far difficult track movement would jihadist mr phillips former head national counter terrorism security office said use analogy needle haystack haystack get lot bigger summer month difficult turkish authority GRAPHIC FADEL SENNA MARWEN FARHANI TRANSTERRA MEDITunisians protest terrorism outside bardo museum left bullet hole one window british victim sally adey husband robert tunisia stunned home grown terror tunisia stunned home grown terror tunisia stunned home grown terror tunisia stunned home grown terror
#
# Full text for article: 33
# tunisia attack UK ups wimbledon security seizes drone london june one britain biggest sporting event wimbledon begin monday scotland yard tightened security seized drone flying england lawn tennis club report said number briton killed tunisia attack could reach briton brought back tunisia attack tribute paid victim identification victim continuing report said british toll among dead likely reach least killed attack tunisian hotel ministry IS claim responsibility tunisia kuwait terror attack killed IS shooting tunisia beach resort turn horror house loud bang blood beach tunisian resort survivor recall horror terror attack tunisia trigger security clampdown tunisia attack UK ups wimbledon security seizes drone tunisia attack UK ups wimbledon security seizes drone tunisia attack UK ups wimbledon security seizes drone tunisia attack UK ups wimbledon security seizes drone
#
# Full text for article: 34
# blast istanbul tourist square kill foreigner among injured india jan least people killed injured explosion rocked central istanbul square tuesday turkey haberturk television said blast took place istanbul historic sultanahmet square major tourist attraction turkey populous city may caused suicide bomber haberturk said without citing source however official word cause blast foreign tourist germany norway among wounded istanbul blast say CNN turk turkish authority suspect terror attack cause blast government official said turkish police sealed sultanahmet square blast reuters witness said ambulance rushed scene explosion close blue mosque hagia sophia state run anadolu agency said several police medic sent area turkey witnessed two major bomb attack last year people killed islamic state suicide attack town suruc near turkey border syria july two suicide bomb october killed people outside ankara main train station people gathered peace rally prosecutor office said turkey deadliest attack carried local islamic state cell blast istanbul tourist square kill foreigner among injured blast istanbul tourist square kill foreigner among injured blast istanbul tourist square kill foreigner among injured blast istanbul tourist square kill foreigner among injured
#
# Full text for article: 35
# attack took place beach luxurious soviva imperial marhaba hotel sousse popular resort mediterranean sea approx km south tunis son swimming sea got around noon suddenly saw flew inflatable balloon shot heard caught child thing running towards hotel waiter security guard started shouting run run sheltered bungalow irish elizabeth brien told RTE radio security service initially reported perpetrator attack two late afternoon interior ministry announced assailant probably one wearing short shirt looked like tourist hid kalashnikov beach umbrella according rafik chelii one chief security service killed spot exchange fire officer kairuan located km west susa known authority kairuan one four sacred city islam next mecca medina jerusalem terrorist sacrifice alive arouse fear make division think attack enough destabilize country li beginning wave attack afraid year tunisia may change face added van buuren tunisia country arab spring series protest started country covered almost arab world refuting dictator relatively well set model transformation time problem radical feeding rank islamic state syria iraq many thousand around thousand foreign fighter formation come tunisia half thousand already returned country many come radical islamic group ansar sharia tunis recognized terrorist organization august fall ben ali dictatorship islamist tunisia attack secular politician march also raised hand tourist armed assailors entered jewel tunisian heritage bardo museum tunis killed people japan italy colombia spain australia france great britain belgium among victim also three pole group people visiting museum ten wounded bloody attack tunisia bloody attack tunisia bloody attack tunisia bloody attack tunisia
#
# Full text for article: 36
# tunisia taking stock dead survivor TUNIS still shaken friday brazen attack killed people national bardo museum heart capital two day tunisian official spent independence day public holiday evacuating dead wounded foreign tourist burying family dead wounded begun arriving tunis alongside trail foreign politician diplomat bring casualty home four polish tourist medically evacuated military plane friday afternoon two french woman transferred back france three italian sent home thursday night sad overwhelming said tunisian anesthetist watched group foreigner driven hospital gate declined identified citing ministry health rule expressed shock dismay attack killed many foreign visitor tunisian government mobilized small army medical personnel security official protocol officer handle casualty assist family country overwhelmed anger remorse wednesday attack identifying dead wounded difficult painful experience head morgue said victim badly disfigured shooting doctor said greater difficulty reaching family member bringing tunisia identify deceased one dead carried australian passport proved colombian origin closest relative live colombia said weekend psychologist open door tunisian working museum caught attack see tunisian picking said saying terrorism universal problem must confront must beaten extraordinary determined rebound let beaten tunisia taking stock dead survivor tunisia taking stock dead survivor tunisia taking stock dead survivor tunisia taking stock dead survivor
#
# Full text for article: 37
# fatal museum attack blow tunisia democratic shift BYLINE DAVID KIRKPATRICK reporting contributed farid farid hend hassassi farah samti tunis maïa de la baume paris elisabetta povoledo rome mayy el sheikh cairo tom mashberg boston CAIRO gunman military uniform killed people wednesday midday attack museum downtown tunis dealing new blow tourist industry vital tunisia struggle consolidate transition democracy arab spring revolt tunisian official initially said attacker took hostage killed nine people including seven foreign visitor two tunisian security force retook museum four hour later however death toll doubled raising question point hostage died prime minister habib essid said news conference security force killed two gunman inside museum two three accomplice might still large said foreign visitor including polish italian spanish german tourist well two tunisian one member security force killed attack least others wounded mr essid urged national unity calling attack first operation kind ever occur tunisia struck crucial tourist economy show compassion mercy defending country said two gunman killed believed tunisian said yet identity motivation immediately clear claim responsibility tunisia arab world successful democracy recently completed first free presidential election peaceful rotation political power security force also struggled quash occasional attack islamist extremist especially mountain tunisia emerged one biggest source foreign fighter joining islamic state also known ISIS ISIL syria iraq democracy provided new freedom speech group recruiter easy find young tunisian captivated promise justice opportunity struggle weight economy suffering year tumult abusive police force left old authoritarian system boubakr hakim tunisian militant known abu moqatel urged support islamic state claimed responsibility earlier assassination two left leaning tunisian politician warned attack come live safety long tunisia ruled islam said report said parliament convenes building adjacent museum historic bardo district capital debating legislation combat terrorism attack began tunisian official said wednesday attacker might originally sought target parliament shifted adjacent museum national bardo museum le formidable security noriko yuki japanese tourist reached tunis wednesday morning cruise italy mother nobuko heard bullet flying head dropped ground younger m yuki said one wounded cheek siege ended death two gunman within four hour initial attack pose new test tunisia democratic transition coming le five month election first parliament first president since ouster zine el abidine ben ali longtime dictator assault appeared tunisia deadliest terrorist attack since truck filled propane detonated outside synagogue island djerba killing people including european tourist since revolution tunisian authority struggled eradicate islamist militant region far coast assault wednesday especially damaging european tourist lifeblood tunisian economy main source foreign currency office president françois hollande france confirmed late wednesday two french citizen died tunis attack seven others wounded piero fassino mayor turin italy told italian television six city hall employee tunis two heard waiting news certain anguish said GRAPHIC PHOTOS victim evacuated wednesday national bardo museum tunis gunman uniform killed people a1 visitor evacuated security force retook museum gunman stormed building wednesday afternoon PHOTOGRAPHS BY HASSENE DRIDI ASSOCIATED PRESS tunisian security service officer took position gunman held hostage national bardo museum near country parliamentary building PHOTOGRAPH BY MOHAMED MESSARA EUROPEAN PRESSPHOTO AGENCY a10 MAPS a10 fatal museum attack blow tunisia democratic shift fatal museum attack blow tunisia democratic shift fatal museum attack blow tunisia democratic shift fatal museum attack blow tunisia democratic shift
#
# Full text for article: 38
# tourist used victim blood survive tunis attack TALES life saving last minute decision visit museum emerged south african international authority scramble locate citizen killed missing injured terror attack tunisia helen esterhuizen seven friend mediterranean cruise decided go bardo national museum tunis made way market instead two gunman disguised police entered museum opened fire fellow passenger MSC splendida killing nine injuring total people including foreigner killed injured speaking en route barcelona esterhuizen said yesterday real miracle meant go museum friend enough museum heard attack nearby market street calm taxi driver picked u later even aware happening got back dock four hour later spending time beach lunch waiting ship thing started appearing suspicious lot police tourist bus escorted military navy diver searching ship aboard ship saw attack TV realise happened said awful scary somebody could beautiful country people amazing kind caring would anyone want hurt tunisia esterhuizen said mood ship sombre people rattled scary think close others came going museum UK newspaper daily mail reported people survived attack smearing blood others playing dead spokesman MCS cruise ingrid roding tudor confirmed south african woman injured attack serious condition hospital husband remaining south african onboard accounted nine passenger killed injured said six passenger still missing spokesman department international relation cooperation nelson kgwete said information number south african caught attack difficult come embassy staff going hospital contact local authority chaotic number south african tunis PANIC police officer journalist outside parliament tunis wednesday gunman stormed museum killed foreign tourist two tunisian picture ZOUBEIR SOUISSI REUTERS lucky escape SA tourist lucky escape SA tourist lucky escape SA tourist lucky escape SA tourist

# %%
i=0
for text in data_train.title_text[(data_train["label_2"]==0)&(data_train['y_pred_ens2']>0.5)]:
    print("Full text for article:",i)
    print(text)
    print("  ")
    i+=1
# Out:
# Full text for article: 0
# turkey france hit attack recent month istanbul turkey tourism industry also taken hit following bomb attack capital ankara october suicide bomber tuesday killed people left wounded istanbul tourist district sultanahmet near major tourist attraction including blue mosque hagia sophia killed german tourist make largest share holidaymaker turkey threatening industry car bomb attack thursday kurdish militant police station housing officer killed wounded score people southeastern turkey turkey already lost russian tourist due weakening rouble spat russia another big supplier visitor chebib said estimated loss turkey tourism income reach billion john podaras partner consultancy hotel development resource said attack bound longer term implication turkish tourism industry turkey tourism profit fell per cent billion third quarter chebib said turkey attracted million visitor generated billion tourism revenue anand said cox king take precaution guide tourist alternate destination following attack turkey france etihad airway early ass impact etihad airway flight booking following recent attack paris istanbul spokesperson abu dhabi airline told gulf news email outside europe egypt tourism industry suffering egypt tourism minister hisham zaazou said last month direct revenue loss tourism since plane crash range million million attack dent tourism popular holiday destination attack dent tourism popular holiday destination attack dent tourism popular holiday destination attack dent tourism popular holiday destination
#
# Full text for article: 1
# tunisia plan arm tourism police deploy hundred reinforcement boost security jihadist gunned people seaside resort police sunday patrolled beach port el kantaoui north sousse worst jihadist attack tunisia history took place friday monday interior minister britain france germany visit seaside riu imperial marhaba hotel south tunis killing took place tunisia interior ministry spokesman mohamed ali aroui refused comment allegation police slow react extra police armed guard protect tourist extra police armed guard protect tourist extra police armed guard protect tourist extra police armed guard protect tourist
#
# Full text for article: 2
# BYLINE ruth pollard middle east correspondent tunis tunisia neighbourhood north west tunisia capital tunis one clutch poor town extremist mosque allowed flourish since overthrow president zine el abidine ben ali one unlicensed mosque city kairouan islamic state inspired gunman seifeddine rezgui believed exposed radical teaching fuelled friday devastating attack one tunisia best known beach resort operating outside state control estimated mosque slated closure tunisian government struggle respond worst ever terror attack soil least people mostly tourist britain ireland germany belgium well several tunisian killed june lone gunman armed kalashnikov grenade attacked sunbather beach resort town sousse kilometre south capital many tunisian despairing government ongoing failure stop extremist gaining foothold say could forced better balance country newly evolving democracy emboldened islamist movement emerging decade harsh repression former president point assassination two left wing politician attack national bardo museum march people killed mostly foreign tourist clear indication extremism growing threat tunisia monday mark one year since self declared leader abu bakr al baghdadi declared caliphate across territory stretch iraq syria libya north sinai region egypt terrorism expert estimate least tunisian gone fight libya iraq syria leaving tunisia unenviable distinction providing foreign fighter islamic state country world rafaa tebib tunis based security expert researcher universite francois rabelais france say government political fight terrorism lay blame foot tunisia moderate islamist party ennada say provided cover renegade mosque gain foothold community say even though islamic state indicated desire take territory tunisia yet managed turned jihad driven solely economic factor say tunisian political analyst youssef cherif economy part ideology tunisia something well entrenched population generation know belongs tunisia muslim world arab world GRAPHIC PHOTO tourist bear flower tunisian flag site deadly attack marhaba beach photo getty image extremism thrives fertile soil poverty revolt beach bloodbath radical mosque slated closure extremism thrives fertile soil poverty revolt beach bloodbath radical mosque slated closure extremism thrives fertile soil poverty revolt beach bloodbath radical mosque slated closure extremism thrives fertile soil poverty revolt beach bloodbath radical mosque slated closure
#
# Full text for article: 3
# slaughter tunisia claim life gentle sydney man terror attack family tragedy tuesday ship docked tunisia mr camelo parent among group tourist decided visit national bardo museum country capital tunis GRAPHIC THREE PHOTOS clockwise top javier camelo selfie father jose mother miriam italian city palermo javier parent graduation last week tunisian force secure museum following attack photo facebook AFP slaughter tunisia claim life gentle sydney man terror attack family tragedy slaughter tunisia claim life gentle sydney man terror attack family tragedy slaughter tunisia claim life gentle sydney man terror attack family tragedy slaughter tunisia claim life gentle sydney man terror attack family tragedy
#
# Full text for article: 4
# tunisian security force wednesday killed dangerous terrorist arrested others confiscated weapon ammunition anti terrorism operation near tunisian capital according interior ministry said planned carry simultaneous terrorist operation police came around GMT two hour exchange fire woman preferred named said gunman neighborhood recently rented house solidarity solidarity stronghold salafist jihadist movement tunisia november suicide bomber hossam al abdali year old resident district manihila blew bus presidential security personnel near headquarters ministry interior heart tunisian capital killed security personnel process adopted islamic state dictator zine el abidine ben ali violence jihadi group escalated tunisia one linked al qaeda islamic maghreb planned turn tunisia first islamic emirate north africa foreign tourist security personnel killed three deadly attack adopted islamic extremist state organization tunisian age killed tunisia since according official statistic military security personnel foreign tourist tunisian national especially syria iraq libya according report released last july UN working group use mercenary tunisian police kill two terrorist stop planned simultaneous attack tunisian police kill two terrorist stop planned simultaneous attack tunisian police kill two terrorist stop planned simultaneous attack tunisian police kill two terrorist stop planned simultaneous attack
#
# Full text for article: 5
# jeddah mar19 BNA OIC secretary general mr iyad ameen madani strongly condemned terrorist attack took place wednesday morning march bardo national museum tunis capital republic tunisia resulted several casualty injury among foreign tourist tunisian citizen secretary general voiced view terrorist attack run counter every human principle antithesis every religious tenet undermine social fabric obstruct building political institution deny right people secure stable life madani expressed OIC full solidarity people government tunisia combating terrorism confronting seek disrupt country security stability derail economy development tarnish history stand model coexistence tolerance enlightenment also secretary general stressed need combat phenomenon terrorism understand context dismantle environment nurture delegitimize slogan track party feed use achieve political agenda ensure proponent supporter tracked security force brought justice context secretary general reiterated OIC principled unwavering position condemns terrorism form manifestation also extended sincere condolence family victim best wish prompt recovery injured h NBNA GMT publishing right reserved bahrain news agency OIC condemns bardo museum terror attack OIC condemns bardo museum terror attack OIC condemns bardo museum terror attack OIC condemns bardo museum terror attack
#
# Full text for article: 6
# bahrain condemns terrorist attack tunisia manama mar BNA ministry foreign affair kingdom bahrain today strongly condemns terrorist attack targeted headquarters parliament republic tunisia bardo museum claiming life number tourist innocent tunisian citizen ministry warns cowardly terrorist attack target accelerated tangible effort exerted brotherly republic tunisia underpin stability security also affirms kingdom bahrain support necessary crucial measure republic tunisia take secure citizen resident safety confront extremism terrorism land ministry foreign affair express sincere condolence kingdom bahrain relative family innocent casualty wish speedy recovery injured terrorist act reiterates rejection form violence terrorism regardless motif justification also affirms solidarity international community effort aiming root terrorism eliminate manifestation risk maintain international security stability MJBNA GMT 18publishing right reserved bahrain news agency bahrain condemns terrorist attack tunisia bahrain condemns terrorist attack tunisia bahrain condemns terrorist attack tunisia bahrain condemns terrorist attack tunisia
#
# Full text for article: 7
# egypt archaeological complex luxor bank nile river already targeted tourist two occasion six member al gama al islamiyya terrorist organization killed tourist four egyptian citizen hatshepsut temple june year man bomber left four wounded temple karnak morocco may explosion killed people casablanca april bomb exploded cafe city marrakesh leaving people dead tunisia march year three gunman stormed bardo museum tunisian capital killing people including tourist end june year old seifeddine rezgui opened fire guest imperial marhaba hotel sousse killing tourist british sightseeing sightseeing sightseeing sightseeing
#
# Full text for article: 8
# NEW YORK family canadian volunteer dedicated alleviating poverty africa group fearless german traveling turkey middle east iraqi went baghdad take refuge jihadist violence hometown speech therapist fell love indonesia among victim terrorist attack last week four country bloodshed left friend relative stunned randomness killing site attack targeted conventional mall iraq hotel ouagadougou capital burkina faso shopping mall jakarta traditional sultanahmet square historical cultural heart istanbul attack also highlight growing rivalry islamic state al qaeda organization determined prove jihadist faith barbarism istanbul suicide bomber crowd near blue mosque hagia sophia apparently chose group german tourist arrived day dead retired including butcher teacher construction manager father son gã¼nther steffen hã ppner also died blast karin franke dã¼tz year old daughter retired teacher recalled anxiety felt learned mother going turkey common destiny tragedy common destiny tragedy common destiny tragedy common destiny tragedy
#
# Full text for article: 9
# president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus explosion struck bus carrying member tunisia presidential guard capital tuesday killing least people wounding dozen others government described terrorist attack blast tree lined avenue heart tunis new blow country seen model region struggled islamic extremist violence radical gunman staged two attack earlier year killed people devastated tourism industry rattled young democracy president beji caid essebsi bus time declared state emergency curfew tunis region convened emergency meeting security council wednesday morning speaking national television said tunisia war terrorism urged international co operation extremist killed hundred around europe mideast recent week paris beirut russian plane shot egypt police fanned throughout central tunis tuesday explosion ambulance rushed scene evacuating wounded dead top government minister visited scene attack cordoned police earlier month tunisian authority announced dismantling cell said planned attack police station hotel seaside city sousse kilometre southeast tunis sousse one target attack earlier year u secretary state john kerry visiting tunis earlier month pledged expanded economic security support tunisia whose popular uprising unleashed democracy movement across region known arab spring tunisia arab spring country solidified new democracy facing serious economic security challenge tourism industry hit especially hard year shooting luxury beach hotel sousse last june killed people mostly tourist march attack islamist extremist tunisia famed bardo museum near capital killed people president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus
#
# Full text for article: 10
# ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism one guy tunisia one guy france one guy kuwait three loose cannon wreaking havoc deadly disparate decentralized havoc three different way single day friday strike indeed leaderless hardest blow came fragile tunisia lone gunman posing tourist cut least people mediterranean beach resort sousse hardest simply blow landed overwhelmingly vacationer future traveller dare set foot country another devastating day tunisia coming le six month attack tourist bardo museum tunis several year attack timed holy month tunisian blogger activist lina ben mhenni told star mhenni faced repeated threat speaking extremism travel bodyguard assigned tunisian interior ministry even though object heavy handed nature reconstituted police state revolution intended overthrow mhenni ended conversation abruptly single security escort arrived join hour long drive sousse rally beginning take shape stand solidarity everyone civilian tourist worker foreigner tunisian alike suffered today ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism
#
# Full text for article: 11
# dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france attack friday tunisia kuwait france raised fear adherent islamic state following order tunisia soon gunman reportedly disguised tourist opened umbrella pulled kalashnikov shooting least people death beach resort security force killed tunisia high alert since march gunman attacked bardo museum tunis killing undoubtedly hurt country vital tourism industry islamic state claim responsibility SITE intelligence group report could indication group increasing interest tunisia hailed sole remaining success story arab spring could also part battle al qaeda insurgent country gained strength among unemployed disenfranchised tunisian youth newer generation loyal islamic state dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france
#
# Full text for article: 12
# dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france muslim embark hasten toward jihad abu mohammed al adnani said message circulated social medium attack friday tunisia kuwait france raised fear adherent islamic state following order tunisia soon gunman reportedly disguised tourist opened umbrella pulled kalashnikov shooting least people death beach resort security force killed tunisia high alert since march gunman attacked bardo museum tunis killing undoubtedly hurt country vital tourism industry islamic state claim responsibility SITE intelligence group report could indication group increasing interest tunisia hailed sole remaining success story arab spring could also part battle al qaeda insurgent country gained strength among unemployed disenfranchised tunisian youth newer generation loyal islamic state dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france
#
# Full text for article: 13
# third suspect tunisia identified yet caught tunisian security force looking third man suspected wednesday attack national bardo museum foreign tourist tunisian police officer two gunman killed tunisian shaken attack massacre heart capital right next parliament islamic state group smaller extremist movement okba ibn nafaa claimed responsibility interior ministry released footage two gunman walking museum lobby along corridor attack one point encounter man descending flight stair appear exchange brief greeting hurriedly departs man among people arrested suspected accomplice ministry also released photograph gunman killed security force identified yassine abidi hatem khachnaoui kasserine western tunisia official said police still searching maher ben moudli kaidi believe co ordinated attack resident working class area northern tunis abidi lived said kaidi also lived nearby yet abidi action divided neighbourhood attending funeral neighbour relative muslim society like tunisia obligation yet said would revolted done third suspect tunisia identified yet caught third suspect tunisia identified yet caught third suspect tunisia identified yet caught third suspect tunisia identified yet caught
#
# Full text for article: 14
# warning tip iceberg group calling yemeni branch islamic state claimed responsibility friday pair suicide bombing sanaa killed people injured hundred others true attack yemen war torn capital would mark deadliest islamic state assault outside stronghold iraq syria bloodshed came heel siege wednesday bardo museum tunisia people died michelle shephard report escalating violence yemen mitch potter examines aftermath tunis taking measure badly wednesday attack rocked cradle arab spring full story a14 deadly expansion islamic state deadly expansion islamic state deadly expansion islamic state deadly expansion islamic state
#
# Full text for article: 15
# islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist tunisian authority said two slain gunman clear link extremist analyst said existing militant cell merely inspired group rather deliberately establishing presence across north africa four others said supporter cell also arrested central tunisia far group claiming allegiance al qaeda north african branch active health ministry said death toll rose thursday foreign tourist nearly people wounded three tunisian killed including two attacker tunisian stepped around trail blood broken glass outside museum rally solidarity victim foreign tourist cruise ship country fledgling democracy marcher carried sign saying terrorism tunisia bloodied still standing claiming responsibility attack islamic state group issued statement audio jihadi website applauding dead gunman knight blessed invasion one den infidel vice muslim tunisia several well armed group neighbouring chaotic libya already pledged allegiance islamic state based iraq syria attack magnitude tunisia country emerge arab spring uprising functioning democracy raised concern spread extremism rest north africa confronted poor economy young tunisian disproportionately gone abroad fight extremist group libya syria iraq including affiliated islamic state upon return home may decided carry attack tunisian authority estimated young people left country fight radical group returned tunisia deadly group oqba ibn nafaa brigade allied al qaeda based mountain near algerian border previously confined attack political figure security service tunisia particularly vulnerable attack economy struggled since country became birthplace arab spring overthrowing dictator death many foreigner damage tunisia tourism industry draw thousand foreigner beach oasis ancient roman ruin industry started recover year decline two cruise ship passenger among dead quickly left tunis early thursday islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist
#
# Full text for article: 16
# gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year foreign tourist scrambled panic wednesday militant stormed museum tunisia capital killed least people shooting anything moved witness said authority launched manhunt two three accomplice attack official said killed people nearly tourist poland italy spain germany colombia least two people killed gunman tunisian people several country injured attack authority said poland reported wounded italy said least six hospital tunis doctor said also french japanese belgian patient want people tunisia understand firstly lastly war terror savage minority group frighten u said newly elected president beji caid essebsi evening address nation fight continue exterminated tunisian overthrew dictator kicked arab spring spread across region uprising built new democracy country also struggled economic problem attack extremist prime minister habib essid identified slain gunman yassine laabidi hatem khachnaoui tunisian twitter account associated extremist islamic state group based syria iraq described overjoyed attack urging tunisian follow brother according rita katz SITE u based organization monitor militant group assault bardo tunisia largest museum housed 15th century palace began sometime noon local time score european tourist visiting dozen tourist scrambled museum linking arm clutching child tunisian police security force pointed weapon building museum fourkilometres city centre located near national parliament building evacuated hour police ended siege thousand tunisian flocked downtown landmark bourguiba avenue revolution took place nighttime rally chanted free tunisia defiance terrorism tunisia stable country region struggled violence islamic extremist sworn allegiance al qaeda islamic state group disproportionately large number tunisian recruit according government estimate joined islamic state fighter syria iraq many received training neighbouring libya gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year
#
# Full text for article: 17
# backgrounder deadly attack egypt since least one french tourist killed people wounded blast cairo populous al hussein district sunday evening following major deadly attack hit egypt recent year april suicide bomber wounded seven including two israeli italian swede near egyptian museum downtown cairo april explosion near open market downtown cairo killed least four people including french woman two french suspected suicide bomber wounded others oct series bombing taba hilton hotel egypt sinai peninsula killed including israeli injured sept egyptian security force attacked islamic militant searching hideout suburb cairo killed four militant nov gunman killed foreign tourist four egyptian ancient temple near southern city luxor attack dealt heavy blow country tourist sector sept two gunman killed nine german tourist egyptian driver outside museum downtown cairo april four islamic militant shot dead greek tourist wounded others outside hotel cairo oct militant attacked bus southern egypt killing british tourist injuring three british tourist egyptian driver sept gunman killed two german tourist two egyptian red sea resort hurghada aug gunman killed year old spanish boy injured three others firing tourist bus southern egypt march islamic militant fired nile cruiser southern egypt killing german woman tourist nov motorcade egyptian prime minister muhammad naquib sedki attacked passing school sedki escaped attack unscathed school girl killed least injured feb bomb blew coffee shop downtown cairo killing one swede turk egyptian wounding others british woman tourist killed southern egypt egyptian writer criticized religious extremist shot dead gunman riding motorcycle backgrounder deadly attack egypt since backgrounder deadly attack egypt since backgrounder deadly attack egypt since backgrounder deadly attack egypt since
#
# Full text for article: 18
# backgrounder deadly attack egypt since least one french tourist killed people wounded blast cairo populous al hussein district sunday evening following major deadly attack hit egypt recent year april suicide bomber wounded seven including two israeli italian swede near egyptian museum downtown cairo april explosion near open market downtown cairo killed least four people including french woman two french suspected suicide bomber wounded others oct series bombing taba hilton hotel egypt sinai peninsula killed including israeli injured sept egyptian security force attacked islamic militant searching hideout suburb cairo killed four militant nov gunman killed foreign tourist four egyptian ancient temple near southern city luxor attack dealt heavy blow country tourist sector sept two gunman killed nine german tourist egyptian driver outside museum downtown cairo april four islamic militant shot dead greek tourist wounded others outside hotel cairo oct militant attacked bus southern egypt killing british tourist injuring three british tourist egyptian driver sept gunman killed two german tourist two egyptian red sea resort hurghada aug gunman killed year old spanish boy injured three others firing tourist bus southern egypt march islamic militant fired nile cruiser southern egypt killing german woman tourist nov motorcade egyptian prime minister muhammad naquib sedki attacked passing school sedki escaped attack unscathed school girl killed least injured feb bomb blew coffee shop downtown cairo killing one swede turk egyptian wounding others british woman tourist killed southern egypt egyptian writer criticized religious extremist shot dead gunman riding motorcycle backgrounder deadly attack egypt since backgrounder deadly attack egypt since backgrounder deadly attack egypt since backgrounder deadly attack egypt since
#
# Full text for article: 19
# belarus strongly condemns terrorist attack turkey belarusian foreign ministry wednesday strongly categorically condemned terrorist attack airport istanbul terrorist attack turkey attack taken place europe demonstrated strong threat posed terrorism recognizes border norm civilization ministry said statement belarusian president alexander lukashenko behalf people belarus personally extended sincere condolence turkish president recep tayyip erdogan relative loved one people killed terrorist attack three suicide bomber opened fire blew international terminal istanbul ataturk airport tuesday killing least people injuring others belarusian consulate istanbul wednesday morning reported according preliminary data belarusian among victim incident belarusian foreign ministry recommended belarusian tourist refrain visiting crowded place turkey turkey declared day national mourning wednesday deadly istanbul airport attack belarus strongly condemns terrorist attack turkey belarus strongly condemns terrorist attack turkey belarus strongly condemns terrorist attack turkey belarus strongly condemns terrorist attack turkey
#
# Full text for article: 20
# backgrounder recent terror attack turkey glance terrorist attack istanbul ataturk airport tuesday killed people injured many others latest spate terror attack country station town midyat southeastern turkey killed three shuttle bus central istanbul main tourist district central istanbul shopping tourism district wounding least people bomber later identified turkish capital city ankara killing least people istanbul historic sultanahmet square islamic state istanbul sabiha gokcen airport located asian side others wounded two blast hit ankara central railway deadly attack kind turkish soil backgrounder recent terror attack turkey glance backgrounder recent terror attack turkey glance backgrounder recent terror attack turkey glance backgrounder recent terror attack turkey glance
#
# Full text for article: 21
# denmark expanding travel order egypt GYPT danish tourist advised go part egypt sharm el sheikh efter bomb attack bus sunday killed four people danish ministry foreign affair changing travel guide egypt popular holiday destination sharm el sheikh last place sinai peninsula tourist still travel safely according travel guide denmark extends travel order egypt denmark extends travel order egypt denmark extends travel order egypt denmark extends travel order egypt
#
# Full text for article: 22
# tunisia corner SalafismoDATELINE TunisiaApproaching al fatah mosque long street liberty see several row men sidewalk praying orderly manner pin inside friday prayer muezzin sung call prayer minute one afternoon temple center tunis meter great synagogue fatah one tunisian mosque symbol rise salafism stream strict islam many target violence shake wednesday brutality terrorist attack bardo museum people tourist murdered tunisia corner salafism tunisia corner salafism tunisia corner salafism tunisia corner salafism
#
# Full text for article: 23
# tunisia corner SalafismoDATELINE TunisiaApproaching al fatah mosque long street liberty see several row men sidewalk praying orderly manner pin inside friday prayer muezzin sung call prayer minute one afternoon temple center tunis meter great synagogue fatah one tunisian mosque symbol rise salafism stream strict islam many target violence shake wednesday brutality terrorist attack bardo museum people tourist murdered tunisia corner salafism tunisia corner salafism tunisia corner salafism tunisia corner salafism
#
# Full text for article: 24
# tunisia advanced process democratic transition unique arab world time country seriously affected terrorist violence high level jihadist mobilization death wednesday least foreign tourist including two spaniard three tunisian assault carried several armed men together parliament tunisia subsequent entrenchment hostage taking nearby bardo museum constitute expression violence mobilization number attack tunisia multiplied extraordinarily since half perpetrated military although police religious figure institution well citizen whose conduct conform rigorism demanded islamic extremist also target usual violence perpetrated mainly ansar al sharia tunisia AST also al qaeda islamic maghreb AQIM maintains link AST al morabitãºn okba bin nafa aligned state islamic EI salafists jihadist developed easily tunisia general amnesty overthrow president ben ali allowed many latter leave prison mid following assassination two important opposition leader islamist ennahda distance AST designate terrorist organization meanwhile tunisia became country jihadist mobilization related syria iraq reached greater height tunisian joined ISI al nusra front hundred returned others relocated IS libya implies serious potential political destabilization social bankruptcy tunisia even though citizen accept secularized exercise politics favor democracy tourism great importance economic development country therefore consolidation new regime since one attack tourist interest october sousse precisely first suicide country since april also tourist target yerba attempting parliament killing tourist tunisia unity government nida tune secular party parliamentary election october presidential election december ennahda jihadist present clear immediate strategy tunisian authority adequately respond terrorist challenge european one offer unequivocal support complicated lasting task PG fernando reinares principal investigator global terrorism program elcano royal institute terrorism democracy terrorism democracy terrorism democracy terrorism democracy
#
# Full text for article: 25
# four people including three believed south korean christian pilgrim killed yesterday bomb tore bus near egypt border israel sinai peninsula bus heading taba border crossing taking pilgrim visit st catherine monastery foot mount sinai front half engulfed explosion bombing said authority likely work terrorist insurgent based sinai marked dramatic shift current campaign egyptian regime date targeted military police tour company including take thousand british visitor egypt red sea beach every year fear herald return previous bombing campaign targeting people killed bomb one three planted time peninsula exploded taba hilton hotel le mile point yesterday attack pilgrim killed bomb attack sinai bus pilgrim killed bomb attack sinai bus pilgrim killed bomb attack sinai bus pilgrim killed bomb attack sinai bus
#
# Full text for article: 26
# AT LEAST people killed morocco yesterday suspected suicide bomber detonated device busy square tourist marrakesh khalid naciri communication minister compared attack one casablanca may left people dead including suicide bomber terrorist act said deliberate criminal act morocco facing threat may deal determinedly although one yet claimed responsibility attack men claiming moroccan member al qaida north african wing appeared video last week threatening attack moroccan interest foreign office estimate british tourist visit morocco year many head straight marrakesh developed chic reputation bountiful market architecture steeped history killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh
#
# Full text for article: 27
# AT LEAST people killed morocco yesterday one briton injured suspected suicide bomber detonated device busy square tourist marrakesh terrorist act said deliberate criminal act morocco facing threat may deal determinedly although one yet claimed responsibility attack men claiming moroccan member al qaeda north african wing appeared video last week threatening attack moroccan interest foreign office estimate british tourist visit morocco year killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh killed caf eacute terrorist target tourist marrakesh
#
# Full text for article: 28
# BRITAIN placed heightened alert police announced extra security public event weekend following terror attack france tunisia kuwait last night foreign office urged tourist imperial marhaba hotel hotel club riu bellevue tunisia stay indoors advertise location attacker might still large shooting beach left least dead including number briton travel company airline said holidaymaker fly tunisia could change plan free charge tunisia become key target jihadist attack one country undergone relatively successful transition democracy following arab spring remained open western value time contributed foreign jihadist war syria anywhere else march people killed attack bardo museum tunis tourist apart security officer cleaning lady BRITAIN placed britain alert copycat attack major event BRITAIN placed britain alert copycat attack major event BRITAIN placed britain alert copycat attack major event BRITAIN placed britain alert copycat attack major event
#
# Full text for article: 29
# tunisian police sacked museum attack world bulletin five leading tunisian security official sacked yesterday last week terrorist attack tourist tunis museum people killed ousted official include director tunisia tourist police police chief neighbourhood around national bardo museum tunisian police sacked museum attack world bulletin tunisian police sacked museum attack world bulletin tunisian police sacked museum attack world bulletin tunisian police sacked museum attack world bulletin
#
# Full text for article: 30
# third gunman run tunis museum massacre twenty foreign tourist policeman killed wednesday attack tunis first assault claimed islamic state iraq levant isil north african country birthplace arab spring interior ministry said saturday issued arrest warrant maher ben moudli kaidi tunisian suspect described dangerous terrorist element people believed linked atrocity also arrested tunisia newspaper yesterday demanded authority combat extremism essential really take action le quotidien wrote including control mosque influence uncontrollable religious fanatic le temp called urgent draconian measure withdrawing citizenship terrorist pledge allegiance enemy authority say many tunisian gone iraq syria libya join isil jihadist group tunisian soldier killed two others injured yesterday vehicle hit landmine planted terrorist mountainous region near algerian border third gunman run tunis museum massacre third gunman run tunis museum massacre third gunman run tunis museum massacre third gunman run tunis museum massacre
#
# Full text for article: 31
# tunis massacre gunman trained militant libya terror camp two gunman massacred people attack museum tunis week trained militant libya isil establishing presence terrorist slipped across border december received weapon training neighbouring country said rafik chelli secretary state security added tunisian authority detail exactly trained group name location several suspected training camp libya including benghazi derna city isil foothold isil claimed responsibility attack lauding gunman knight caliphate praising blessed invasion one den infidel vice muslim tunisia clear whether isil organised assault national bardo museum directly gave blessing operation executed militant speculation gunman link oqba ibn nafaa brigade allied al qaeda based mountain near algerian border gunman yassine laabidi hatem khachnaoui killed people tunisian policeman tourist including sally adey retired solicitor shropshire tunis massacre gunman trained militant libya terror camp tunis massacre gunman trained militant libya terror camp tunis massacre gunman trained militant libya terror camp tunis massacre gunman trained militant libya terror camp
#
# Full text for article: 32
# tunisia stunned home grown terror POLICE tunisia arrested nine people connection terrorist attack bardo museum yesterday british woman named among tourist killed islamic state iraq levant isil claimed responsibility wednesday attack two gunman armed kalashnikov assault rifle fired indiscriminately inside museum tunis british woman died identified sally adey retired solicitor shropshire whose husband robert survived shooting raid shocked tunisia regarded bastion moderate islam success story emerge arab spring fear attack could cripple country vital tourism sector isil praised two gunman shot dead police audio recording arabic calling knight islamic state dead terrorist dressed sweatshirt trainer identi fied hatem al khashnawi yassin al abidi reportedly tunisian abidi spent time iraq libya according tunisian medium report known authority anything special said habib essid tunisian prime minister affiliation clear moment added tourist killed wednesday attack nearly dozen country including france belgium italy spain poland australia colombia tunisia nine travelled MSC splendida cruise ship docked port tunis hour shooting simply police searching people thought terrorist venture despite moderate view tunisian country harbour hard core islamist extremist emerged since democratic revolution four year ago tunisian believed make largest foreign contingent fighting isil around volunteer flocking syria iraq recently libya two large cruise ship company costa cruise MSC cruise said cancelled stop tunis time two german tour company said halting trip tunis nearby beach resort former head britain counter terrorism service warned yesterday vast number holidaymaker travelling turkey summer would make far difficult track movement would jihadist mr phillips former head national counter terrorism security office said use analogy needle haystack haystack get lot bigger summer month difficult turkish authority GRAPHIC FADEL SENNA MARWEN FARHANI TRANSTERRA MEDITunisians protest terrorism outside bardo museum left bullet hole one window british victim sally adey husband robert tunisia stunned home grown terror tunisia stunned home grown terror tunisia stunned home grown terror tunisia stunned home grown terror
#
# Full text for article: 33
# tunisia attack UK ups wimbledon security seizes drone london june one britain biggest sporting event wimbledon begin monday scotland yard tightened security seized drone flying england lawn tennis club report said number briton killed tunisia attack could reach briton brought back tunisia attack tribute paid victim identification victim continuing report said british toll among dead likely reach least killed attack tunisian hotel ministry IS claim responsibility tunisia kuwait terror attack killed IS shooting tunisia beach resort turn horror house loud bang blood beach tunisian resort survivor recall horror terror attack tunisia trigger security clampdown tunisia attack UK ups wimbledon security seizes drone tunisia attack UK ups wimbledon security seizes drone tunisia attack UK ups wimbledon security seizes drone tunisia attack UK ups wimbledon security seizes drone
#
# Full text for article: 34
# blast istanbul tourist square kill foreigner among injured india jan least people killed injured explosion rocked central istanbul square tuesday turkey haberturk television said blast took place istanbul historic sultanahmet square major tourist attraction turkey populous city may caused suicide bomber haberturk said without citing source however official word cause blast foreign tourist germany norway among wounded istanbul blast say CNN turk turkish authority suspect terror attack cause blast government official said turkish police sealed sultanahmet square blast reuters witness said ambulance rushed scene explosion close blue mosque hagia sophia state run anadolu agency said several police medic sent area turkey witnessed two major bomb attack last year people killed islamic state suicide attack town suruc near turkey border syria july two suicide bomb october killed people outside ankara main train station people gathered peace rally prosecutor office said turkey deadliest attack carried local islamic state cell blast istanbul tourist square kill foreigner among injured blast istanbul tourist square kill foreigner among injured blast istanbul tourist square kill foreigner among injured blast istanbul tourist square kill foreigner among injured
#
# Full text for article: 35
# attack took place beach luxurious soviva imperial marhaba hotel sousse popular resort mediterranean sea approx km south tunis son swimming sea got around noon suddenly saw flew inflatable balloon shot heard caught child thing running towards hotel waiter security guard started shouting run run sheltered bungalow irish elizabeth brien told RTE radio security service initially reported perpetrator attack two late afternoon interior ministry announced assailant probably one wearing short shirt looked like tourist hid kalashnikov beach umbrella according rafik chelii one chief security service killed spot exchange fire officer kairuan located km west susa known authority kairuan one four sacred city islam next mecca medina jerusalem terrorist sacrifice alive arouse fear make division think attack enough destabilize country li beginning wave attack afraid year tunisia may change face added van buuren tunisia country arab spring series protest started country covered almost arab world refuting dictator relatively well set model transformation time problem radical feeding rank islamic state syria iraq many thousand around thousand foreign fighter formation come tunisia half thousand already returned country many come radical islamic group ansar sharia tunis recognized terrorist organization august fall ben ali dictatorship islamist tunisia attack secular politician march also raised hand tourist armed assailors entered jewel tunisian heritage bardo museum tunis killed people japan italy colombia spain australia france great britain belgium among victim also three pole group people visiting museum ten wounded bloody attack tunisia bloody attack tunisia bloody attack tunisia bloody attack tunisia
#
# Full text for article: 36
# tunisia taking stock dead survivor TUNIS still shaken friday brazen attack killed people national bardo museum heart capital two day tunisian official spent independence day public holiday evacuating dead wounded foreign tourist burying family dead wounded begun arriving tunis alongside trail foreign politician diplomat bring casualty home four polish tourist medically evacuated military plane friday afternoon two french woman transferred back france three italian sent home thursday night sad overwhelming said tunisian anesthetist watched group foreigner driven hospital gate declined identified citing ministry health rule expressed shock dismay attack killed many foreign visitor tunisian government mobilized small army medical personnel security official protocol officer handle casualty assist family country overwhelmed anger remorse wednesday attack identifying dead wounded difficult painful experience head morgue said victim badly disfigured shooting doctor said greater difficulty reaching family member bringing tunisia identify deceased one dead carried australian passport proved colombian origin closest relative live colombia said weekend psychologist open door tunisian working museum caught attack see tunisian picking said saying terrorism universal problem must confront must beaten extraordinary determined rebound let beaten tunisia taking stock dead survivor tunisia taking stock dead survivor tunisia taking stock dead survivor tunisia taking stock dead survivor
#
# Full text for article: 37
# fatal museum attack blow tunisia democratic shift BYLINE DAVID KIRKPATRICK reporting contributed farid farid hend hassassi farah samti tunis maïa de la baume paris elisabetta povoledo rome mayy el sheikh cairo tom mashberg boston CAIRO gunman military uniform killed people wednesday midday attack museum downtown tunis dealing new blow tourist industry vital tunisia struggle consolidate transition democracy arab spring revolt tunisian official initially said attacker took hostage killed nine people including seven foreign visitor two tunisian security force retook museum four hour later however death toll doubled raising question point hostage died prime minister habib essid said news conference security force killed two gunman inside museum two three accomplice might still large said foreign visitor including polish italian spanish german tourist well two tunisian one member security force killed attack least others wounded mr essid urged national unity calling attack first operation kind ever occur tunisia struck crucial tourist economy show compassion mercy defending country said two gunman killed believed tunisian said yet identity motivation immediately clear claim responsibility tunisia arab world successful democracy recently completed first free presidential election peaceful rotation political power security force also struggled quash occasional attack islamist extremist especially mountain tunisia emerged one biggest source foreign fighter joining islamic state also known ISIS ISIL syria iraq democracy provided new freedom speech group recruiter easy find young tunisian captivated promise justice opportunity struggle weight economy suffering year tumult abusive police force left old authoritarian system boubakr hakim tunisian militant known abu moqatel urged support islamic state claimed responsibility earlier assassination two left leaning tunisian politician warned attack come live safety long tunisia ruled islam said report said parliament convenes building adjacent museum historic bardo district capital debating legislation combat terrorism attack began tunisian official said wednesday attacker might originally sought target parliament shifted adjacent museum national bardo museum le formidable security noriko yuki japanese tourist reached tunis wednesday morning cruise italy mother nobuko heard bullet flying head dropped ground younger m yuki said one wounded cheek siege ended death two gunman within four hour initial attack pose new test tunisia democratic transition coming le five month election first parliament first president since ouster zine el abidine ben ali longtime dictator assault appeared tunisia deadliest terrorist attack since truck filled propane detonated outside synagogue island djerba killing people including european tourist since revolution tunisian authority struggled eradicate islamist militant region far coast assault wednesday especially damaging european tourist lifeblood tunisian economy main source foreign currency office president françois hollande france confirmed late wednesday two french citizen died tunis attack seven others wounded piero fassino mayor turin italy told italian television six city hall employee tunis two heard waiting news certain anguish said GRAPHIC PHOTOS victim evacuated wednesday national bardo museum tunis gunman uniform killed people a1 visitor evacuated security force retook museum gunman stormed building wednesday afternoon PHOTOGRAPHS BY HASSENE DRIDI ASSOCIATED PRESS tunisian security service officer took position gunman held hostage national bardo museum near country parliamentary building PHOTOGRAPH BY MOHAMED MESSARA EUROPEAN PRESSPHOTO AGENCY a10 MAPS a10 fatal museum attack blow tunisia democratic shift fatal museum attack blow tunisia democratic shift fatal museum attack blow tunisia democratic shift fatal museum attack blow tunisia democratic shift
#
# Full text for article: 38
# tourist used victim blood survive tunis attack TALES life saving last minute decision visit museum emerged south african international authority scramble locate citizen killed missing injured terror attack tunisia helen esterhuizen seven friend mediterranean cruise decided go bardo national museum tunis made way market instead two gunman disguised police entered museum opened fire fellow passenger MSC splendida killing nine injuring total people including foreigner killed injured speaking en route barcelona esterhuizen said yesterday real miracle meant go museum friend enough museum heard attack nearby market street calm taxi driver picked u later even aware happening got back dock four hour later spending time beach lunch waiting ship thing started appearing suspicious lot police tourist bus escorted military navy diver searching ship aboard ship saw attack TV realise happened said awful scary somebody could beautiful country people amazing kind caring would anyone want hurt tunisia esterhuizen said mood ship sombre people rattled scary think close others came going museum UK newspaper daily mail reported people survived attack smearing blood others playing dead spokesman MCS cruise ingrid roding tudor confirmed south african woman injured attack serious condition hospital husband remaining south african onboard accounted nine passenger killed injured said six passenger still missing spokesman department international relation cooperation nelson kgwete said information number south african caught attack difficult come embassy staff going hospital contact local authority chaotic number south african tunis PANIC police officer journalist outside parliament tunis wednesday gunman stormed museum killed foreign tourist two tunisian picture ZOUBEIR SOUISSI REUTERS lucky escape SA tourist lucky escape SA tourist lucky escape SA tourist lucky escape SA tourist

# %%
i=0
for text in data_train.titles_lemm[(data_train["label_2"]==0)&(data_train['y_pred_ens2']>0.5)]:
    print("Lemmatized title for article:",i)
    print(text)
    print("  ")
    i+=1
# Out:
# Lemmatized title for article: 0
# attack dent tourism popular holiday destination
#
# Lemmatized title for article: 1
# extra police armed guard protect tourist
#
# Lemmatized title for article: 2
# extremism thrives fertile soil poverty revolt beach bloodbath radical mosque slated closure
#
# Lemmatized title for article: 3
# slaughter tunisia claim life gentle sydney man terror attack family tragedy
#
# Lemmatized title for article: 4
# tunisian police kill two terrorist stop planned simultaneous attack
#
# Lemmatized title for article: 5
# OIC condemns bardo museum terror attack
#
# Lemmatized title for article: 6
# bahrain condemns terrorist attack tunisia
#
# Lemmatized title for article: 7
# sightseeing
#
# Lemmatized title for article: 8
# common destiny tragedy
#
# Lemmatized title for article: 9
# president guard targeted tunisian blast kill state emergency declared young democracy capital massive explosion bus
#
# Lemmatized title for article: 10
# ISIS follower dangerous leader carnage tunisia kuwait france latest example terrorism
#
# Lemmatized title for article: 11
# dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france
#
# Lemmatized title for article: 12
# dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france
#
# Lemmatized title for article: 13
# third suspect tunisia identified yet caught
#
# Lemmatized title for article: 14
# deadly expansion islamic state
#
# Lemmatized title for article: 15
# islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist
#
# Lemmatized title for article: 16
# gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year
#
# Lemmatized title for article: 17
# backgrounder deadly attack egypt since
#
# Lemmatized title for article: 18
# backgrounder deadly attack egypt since
#
# Lemmatized title for article: 19
# belarus strongly condemns terrorist attack turkey
#
# Lemmatized title for article: 20
# backgrounder recent terror attack turkey glance
#
# Lemmatized title for article: 21
# denmark extends travel order egypt
#
# Lemmatized title for article: 22
# tunisia corner salafism
#
# Lemmatized title for article: 23
# tunisia corner salafism
#
# Lemmatized title for article: 24
# terrorism democracy
#
# Lemmatized title for article: 25
# pilgrim killed bomb attack sinai bus
#
# Lemmatized title for article: 26
# killed caf eacute terrorist target tourist marrakesh
#
# Lemmatized title for article: 27
# killed caf eacute terrorist target tourist marrakesh
#
# Lemmatized title for article: 28
# BRITAIN placed britain alert copycat attack major event
#
# Lemmatized title for article: 29
# tunisian police sacked museum attack world bulletin
#
# Lemmatized title for article: 30
# third gunman run tunis museum massacre
#
# Lemmatized title for article: 31
# tunis massacre gunman trained militant libya terror camp
#
# Lemmatized title for article: 32
# tunisia stunned home grown terror
#
# Lemmatized title for article: 33
# tunisia attack UK ups wimbledon security seizes drone
#
# Lemmatized title for article: 34
# blast istanbul tourist square kill foreigner among injured
#
# Lemmatized title for article: 35
# bloody attack tunisia
#
# Lemmatized title for article: 36
# tunisia taking stock dead survivor
#
# Lemmatized title for article: 37
# fatal museum attack blow tunisia democratic shift
#
# Lemmatized title for article: 38
# lucky escape SA tourist

# %%
stringlist=["slaughter tunisia claim life gentle sydney man",
            "OIC condemns bardo museum terror attack",
            "bahrain condemns terrorist attack tunisia",
            "dozen dead attack spread fear across world day ISIS spokesman issued warning strike rock tunisia kuwait france",
            "islamic state say attacked museum group claim behind massacre tunisia killed authority say two gunman link terrorist",
            "gunman shot anything moved least massacred militant storm tunisian museum north african country deadliest civilian attack year",
            "backgrounder deadly attack egypt since",
            "belarus strongly condemns terrorist attack turkey",
            "backgrounder recent terror attack turkey glance",
            "1st LD writethru UN chief slam deadly terrorist attack istanbul",
            "BYLINE CEMBRERO RIZZI",
            "pilgrim killed bomb attack sinai bus",
            "killed caf eacute terrorist target tourist marrakesh",
            "tunisia stunned home grown terror",
            "blast istanbul tourist square kill foreigner among injured",
            "bloody attack tunisia",
            "tunisia taking stock dead survivor",
            "fatal museum attack blow tunisia democratic shift",
            "lucky escape SA tourist"]
for strings in stringlist:
    data_train.loc[data_train['titles_lemm'].str.contains(strings),("label_2")]=1
    full_data.loc[full_data['titles_lemm'].str.contains(strings),("label_2")]=1

# %% [markdown]
# ## Redoing label 2 with recoded entries

# %%
labels_2 = data_train.label_2.tolist()

# %%
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", MultinomialNB()),
    ]
)


parameters = {
    "vect__max_df": (0.2, 0.3, 0.4),
    "vect__min_df": (0.009, 0.01, 0.015),
    "vect__ngram_range": ((1,1), (1,3)),  # unigrams or bigrams
    "tfidf__use_idf": ([True]),
    'tfidf__norm': (['l2']),
}

# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=5)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_2)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 2:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'tfidf__norm': ['l2'],
#  'tfidf__use_idf': [True],
#  'vect__max_df': (0.2, 0.3, 0.4),
#  'vect__min_df': (0.009, 0.01, 0.015),
#  'vect__ngram_range': ((1, 1), (1, 3))}
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# done in 1123.049s
#
# Best score: 0.952
# Best parameters set for label 2:
# 	tfidf__norm: 'l2'
# 	tfidf__use_idf: True
# 	vect__max_df: 0.4
# 	vect__min_df: 0.015
# 	vect__ngram_range: (1, 3)

# %%
clf_nb2 = grid_search.best_estimator_
y_pred_nb2 = cross_val_predict(clf_nb2, Fourtit_text, labels_2, n_jobs=4, verbose=2, cv=5, method= 'predict_proba')[:,1]
draw_roc_curve(labels_2, y_pred_nb2 ,"ml_nb_tourist_harm_roc_curve")
draw_precision_curve(labels_2, y_pred_nb2,"ml_nb_tourist_harm_precision_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:  1.7min finished

# %%
#xgb
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", xgb.XGBClassifier()),
    ]
)


parameters = {
    "vect__max_df": (0.1, 0.25, 0.5),
    "vect__min_df": (0.004, 0.005, 0.006),
    "vect__ngram_range": ([(1,1)]),  # unigrams or bigrams
    "tfidf__use_idf": ([True]),
    'tfidf__norm': (['l1']),
    "clf__gamma": ([1]),
    "clf__reg_alpha": (5, 15),
    "clf__reg_lambda": ([0.1]),
    "clf__max_depth": ([25]),
    "clf__n_estimators": ([300]),
    "clf__min_child_weight": ([5]),
    "clf__scale_pos_weight": ([10]),
    "clf__colsample_bytree":(0.15,0.25,0.35),
}

# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=5)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_2)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 2:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'clf__colsample_bytree': (0.15, 0.25, 0.35),
#  'clf__gamma': [1],
#  'clf__max_depth': [25],
#  'clf__min_child_weight': [5],
#  'clf__n_estimators': [300],
#  'clf__reg_alpha': (5, 15),
#  'clf__reg_lambda': [0.1],
#  'clf__scale_pos_weight': [10],
#  'tfidf__norm': ['l1'],
#  'tfidf__use_idf': [True],
#  'vect__max_df': (0.1, 0.25, 0.5),
#  'vect__min_df': (0.004, 0.005, 0.006),
#  'vect__ngram_range': [(1, 1)]}
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# C:\Users\HMueller\anaconda3\lib\site-packages\xgboost\sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [23:24:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# done in 21923.209s
#
# Best score: 0.977
# Best parameters set for label 2:
# 	clf__colsample_bytree: 0.25
# 	clf__gamma: 1
# 	clf__max_depth: 25
# 	clf__min_child_weight: 5
# 	clf__n_estimators: 300
# 	clf__reg_alpha: 15
# 	clf__reg_lambda: 0.1
# 	clf__scale_pos_weight: 10
# 	tfidf__norm: 'l1'
# 	tfidf__use_idf: True
# 	vect__max_df: 0.25
# 	vect__min_df: 0.005
# 	vect__ngram_range: (1, 1)

# %%
clf_xgb2 = grid_search.best_estimator_
y_pred_xgb2 = cross_val_predict(clf_xgb2, Fourtit_text, labels_2, n_jobs=4, verbose=2, cv=5, method= 'predict_proba')[:,1]
draw_roc_curve(labels_2, y_pred_xgb2 ,"ml_xgb_tourist_harm_roc_curve")
draw_precision_curve(labels_2, y_pred_xgb2,"ml_xgb_tourist_harm_precision_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:  2.5min finished

# %%
# Parameters to use for grid search. Uncommenting more parameters will give
# better exploring power but will increase processing time in a combinatorial
# way
pipeline = Pipeline(
    [
        ("vect", CountVectorizer()),
        ("tfidf", TfidfTransformer()),
        ("clf", RandomForestClassifier()),
    ]
)

parameters = {
    "vect__max_df": (0.5,0.6,0.7),
    "vect__min_df": (0.007,0.008,0.009,0.01),
    "vect__ngram_range": ([(1,1)]),  # unigrams or bigrams
    "tfidf__use_idf": ([True]),
    'tfidf__norm': (['l1']),
    "clf__max_depth": ([20]),
    "clf__n_estimators": ([300]),
    "clf__min_samples_leaf": ([10]),
    "clf__class_weight": (["balanced"]),
}


# Find the best parameters for both the feature extraction and the
# classifier
grid_search = GridSearchCV(pipeline, parameters, n_jobs=4, verbose=3, scoring='roc_auc', cv=5)

print("Performing grid search...")
print("pipeline:", [name for name, _ in pipeline.steps])
print("parameters:")
pprint(parameters)
t0 = time()
grid_search.fit(Fourtit_text, labels_2)
print("done in %0.3fs" % (time() - t0))
print()

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set for label 2:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# Performing grid search...
# pipeline: ['vect', 'tfidf', 'clf']
# parameters:
# {'clf__class_weight': ['balanced'],
#  'clf__max_depth': [20],
#  'clf__min_samples_leaf': [10],
#  'clf__n_estimators': [300],
#  'tfidf__norm': ['l1'],
#  'tfidf__use_idf': [True],
#  'vect__max_df': (0.5, 0.6, 0.7),
#  'vect__min_df': (0.007, 0.008, 0.009, 0.01),
#  'vect__ngram_range': [(1, 1)]}
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# done in 1288.943s
#
# Best score: 0.974
# Best parameters set for label 2:
# 	clf__class_weight: 'balanced'
# 	clf__max_depth: 20
# 	clf__min_samples_leaf: 10
# 	clf__n_estimators: 300
# 	tfidf__norm: 'l1'
# 	tfidf__use_idf: True
# 	vect__max_df: 0.7
# 	vect__min_df: 0.009
# 	vect__ngram_range: (1, 1)

# %%
clf_rf2 = grid_search.best_estimator_
y_pred_rf2 = cross_val_predict(clf_rf2, Fourtit_text, labels_2, n_jobs=4, verbose=2, cv=5, method= 'predict_proba')[:,1]
draw_roc_curve(labels_2, y_pred_rf2 ,"ml_rf_tourist_harm_roc_curve")
draw_precision_curve(labels_2, y_pred_rf2,"ml_rf_tourist_harm_precision_curve")
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   5 out of   5 | elapsed:  1.5min finished

# %% [markdown]
# ### Putting everything together for label 2 after recoding

# %%
y_pred_ens2=(y_pred_nb2 + y_pred_xgb2 + y_pred_rf2 )/3

draw_roc_curve(labels_2, y_pred_ens2 ,"ml_ens_tourist_harm_roc_curve")

draw_precision_curve(labels_2, y_pred_ens2 ,"ml_ens_tourist_harm_precision_curve")

data_train['y_pred_ens2']=y_pred_ens2
sep_data=data_train[["label_2",'y_pred_ens2']]
name=spitout + "separation_plot_ml_tourism.pdf"
separation_plot(sep_data, name)

# %%
#dummyfy
y_ens_dum2=(y_pred_ens2>0.5)*1

cm = confusion_matrix(labels_2, y_ens_dum2, labels=clf_rf2.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf_rf2.classes_)
disp.plot()
plt.show()

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35233 entries, 0 to 35232
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   issuing_iso3c        35233 non-null  object
#  1   dest_iso3c           35233 non-null  object
#  2   year                 35233 non-null  float64
#  3   monthnum             35233 non-null  float64
#  4   day                  35233 non-null  float64
#  5   title_text           35233 non-null  object
#  6   text_with_head_lemm  35233 non-null  object
#  7   titles_lemm          35233 non-null  object
#  8   label_0              35233 non-null  float64
#  9   label_1              35233 non-null  float64
#  10  label_2              35233 non-null  float64
#  11  label_3              35233 non-null  float64
#  12  T_H_count            35233 non-null  int64
#  13  alength              35233 non-null  int64
#  14  H_count              35233 non-null  int64
#  15  T_count              35233 non-null  int64
#  16  K_count              35233 non-null  int64
#  17  tourist_harm_1       35233 non-null  int64
#  18  tourist_harm_2       35233 non-null  int64
#  19  fatal_harm           35233 non-null  int64
#  20  y_pred_ens2          35233 non-null  float64
# dtypes: float64(8), int64(8), object(5)
# memory usage: 5.6+ MB

# %% [markdown]
# # Out of sample predictions for entire sample

# %%
# Make predictions

Fourtit_text_main=full_data.title_text.tolist()

y_pred_proba_rf0 = clf_rf0.predict_proba(Fourtit_text_main)
full_data['proba_anyVio_RF'] = y_pred_proba_rf0[:,1]
y_pred_proba_rf1 = clf_rf1.predict_proba(Fourtit_text_main)
full_data['proba_Vio_RF'] = y_pred_proba_rf1[:,1]
y_pred_proba_rf2 = clf_rf2.predict_proba(Fourtit_text_main)
full_data['proba_T_RF'] = y_pred_proba_rf2[:,1]

y_pred_proba_xgb0 = clf_xgb0.predict_proba(Fourtit_text_main)
full_data['proba_anyVio_XGB'] = y_pred_proba_xgb0[:,1]
y_pred_proba_xgb1 = clf_xgb1.predict_proba(Fourtit_text_main)
full_data['proba_Vio_XGB'] = y_pred_proba_xgb1[:,1]
y_pred_proba_xgb2 = clf_xgb2.predict_proba(Fourtit_text_main)
full_data['proba_T_XGB'] = y_pred_proba_xgb2[:,1]

y_pred_proba_nb0 = clf_nb0.predict_proba(Fourtit_text_main)
full_data['proba_anyVio_NB'] = y_pred_proba_nb0[:,1]
y_pred_proba_nb1 = clf_nb1.predict_proba(Fourtit_text_main)
full_data['proba_Vio_NB'] = y_pred_proba_nb1[:,1]
y_pred_proba_nb2 = clf_nb2.predict_proba(Fourtit_text_main)
full_data['proba_T_NB'] = y_pred_proba_nb2[:,1]

full_data.to_csv('output_2022_11.csv',sep=',',encoding='utf-8')
